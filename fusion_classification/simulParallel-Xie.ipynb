# %%
import sys
import os
import numpy as np
import pandas as pd
import torch
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset, Dataset, Subset
from torcheval.metrics import BinaryPrecision, BinaryRecall, BinaryF1Score
from sklearn.model_selection import train_test_split, KFold

# %%
# Append the path for module imports
sys.path.append('../')

# Import custom modules
from modules.cross_attentionb import CrossAttentionB
from modules.dataloader import load_npy_files
from modules.classifier import DenseLayer, BCELoss, BCEWithLogits

# %% [markdown]
# ### Data Loading

# %%
# Load the labels DataFrame
id_label_df = pd.read_excel('../misc/MM-Trailer_dataset.xlsx')

# Define the directories
text_features_dir = 'C:\\Users\\edjin\\OneDrive\\Documents\\Programming Files\\Thesis\\SMCA\\misc\\textStream_BERT\\feature_vectors\\feature_vectors'
audio_features_dir = 'C:\\Users\\edjin\\OneDrive\\Documents\\Programming Files\\Thesis\\SMCA\\misc\\audio_fe\\logmel_spectrograms'
video_features_dir = 'C:\\Users\\edjin\\OneDrive\\Documents\\Programming Files\\Thesis\\SMCA\\misc\\visualStream_ViT\\feature_vectors'

# Load the feature vectors from each directory
text_features = load_npy_files(text_features_dir)
audio_features = load_npy_files(audio_features_dir)
video_features = load_npy_files(video_features_dir)

print(f"Number of text feature vectors loaded: {len(text_features)}")
print(f"Number of audio feature vectors loaded: {len(audio_features)}")
print(f"Number of video feature vectors loaded: {len(video_features)}")
# Out:
# Number of text feature vectors loaded: 1353
# Number of audio feature vectors loaded: 1353
# Number of video feature vectors loaded: 1353

# %%
# Cross Attention Function
def PairCrossAttention(modalityAlpha, modalityBeta, d_out_kq=768, d_out_v=768):
    cross_attn = CrossAttentionB(modalityAlpha.shape[-1], modalityBeta.shape[-1], d_out_kq, d_out_v)
    modalityAlphaBeta = cross_attn(modalityAlpha, modalityBeta)
    return modalityAlphaBeta

# %%
def HadamardProduct(tensor1, tensor2):
    # Ensure both tensors have the same shape
    if tensor1.shape != tensor2.shape:
        raise ValueError("Tensors must have the same shape for Hadamard product.")
    
    # Compute the Hadamard product
    return tensor1 * tensor2

# %%
class EmbracementLayer(nn.Module):
    def __init__(self, d_in, d_out):
        super(EmbracementLayer, self).__init__()
        self.fc = nn.Linear(d_in, d_out)
        self.norm = nn.LayerNorm(d_out)
        self.activation = nn.ReLU()

    def forward(self, video_features, audio_features, text_features):
        # Concatenate features along the last dimension
        combined_features = torch.cat([video_features, audio_features, text_features], dim=-1)
        
        # Apply linear transformation
        transformed_features = self.fc(combined_features)
        
        # Apply normalization and activation
        norm_features = self.norm(transformed_features)
        output = self.activation(norm_features)
        
        return output

# %% [markdown]
# ### Model Training

# %%
def get_optimizer(parameters, lr=1e-3):
    # Create an optimizer, for example, Adam
    return optim.Adam(parameters, lr=lr)

# %%
def train_model(dense_layer, dataloader, criterion, optimizer, device):
    dense_layer.train()  # Set the model to training mode
    total_loss = 0.0

    for batch in dataloader:
        # Assuming batch is a tuple (fused_features, targets)
        fused_features, targets = batch

        # Move tensors to the specified device
        fused_features = fused_features.to(device)
        targets = targets.to(device)

        # Clear gradients
        optimizer.zero_grad()

        # Pass the fused features through the dense layer
        predictions = dense_layer(fused_features).view(-1)    # Ensure correct shape

        # Compute loss
        loss = criterion(predictions, targets)

        # Backward pass and optimization
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    return total_loss / len(dataloader)

# %%
def evaluate_model(dense_layer, dataloader, criterion, device):
    dense_layer.eval()
    total_loss = 0

    # Initialize the metrics for binary classification
    precision_metric = BinaryPrecision().to(device)
    recall_metric = BinaryRecall().to(device)
    f1_metric = BinaryF1Score().to(device)
    
    with torch.no_grad():
        for fused_features, targets in dataloader:
            fused_features, targets = (
                fused_features.to(device),  # Use fused features directly
                targets.to(device).squeeze()
            )

            # Pass the fused features through the dense layer
            predictions = dense_layer(fused_features).view(-1)
            
            # Compute loss
            loss = criterion(predictions, targets)
            total_loss += loss.item()

            # Apply threshold to get binary predictions
            preds = (predictions > 0.5).float()
            
            # Update the precision, recall, and F1 score metrics
            precision_metric.update(preds.long(), targets.long())
            recall_metric.update(preds.long(), targets.long())
            f1_metric.update(preds.long(), targets.long())

    # Compute precision, recall, and F1 score
    precision = precision_metric.compute().item()
    recall = recall_metric.compute().item()
    f1_score = f1_metric.compute().item()

    average_loss = total_loss / len(dataloader)

    print(f"Evaluation Loss: {average_loss:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1_score:.4f}")
    
    return average_loss, precision, recall, f1_score

# %%
def test_model(dense_layer, dataloader, criterion, device):
    dense_layer.eval()  # Set the model to evaluation mode
    total_loss = 0

    # Initialize the metrics for binary classification
    precision_metric = BinaryPrecision().to(device)
    recall_metric = BinaryRecall().to(device)
    f1_metric = BinaryF1Score().to(device)

    with torch.no_grad():
        for fused_features, targets in dataloader:
            fused_features, targets = (
                fused_features.to(device),  # Move fused features to device
                targets.to(device).squeeze()  # Ensure targets are the correct shape
            )

            # Pass the fused features through the dense layer
            predictions = dense_layer(fused_features).view(-1)  
            
            # Compute loss
            loss = criterion(predictions, targets)
            total_loss += loss.item()

            # Apply threshold to get binary predictions
            preds = (predictions > 0.5).float()
            
            # Update the precision, recall, and F1 score metrics
            precision_metric.update(preds.long(), targets.long())
            recall_metric.update(preds.long(), targets.long())
            f1_metric.update(preds.long(), targets.long())

    # Compute precision, recall, and F1 score
    precision = precision_metric.compute().item()
    recall = recall_metric.compute().item()
    f1_score = f1_metric.compute().item()

    average_loss = total_loss / len(dataloader)

    print(f"Test Loss: {average_loss:.4f}")
    print(f"Test Precision: {precision:.4f}")
    print(f"Test Recall: {recall:.4f}")
    print(f"Test F1 Score: {f1_score:.4f}")

    return average_loss, precision, recall, f1_score

# %% [markdown]
# ### Fusion

# %%
# Initialize list to store fused features for each file
fused_features_list = []
labels_list = []
batch_size = 32  # Adjust based on your available memory

for batch_start in range(0, len(text_features), batch_size):
    batch_end = min(batch_start + batch_size, len(text_features))
    batch_text_features = text_features[batch_start:batch_end]
    batch_audio_features = audio_features[batch_start:batch_end]
    batch_video_features = video_features[batch_start:batch_end]
    print(f"Batch: {batch_start}")
    # Loop through all the files in the dataset
    for i in range(len(batch_text_features)):
        # Extract features for the current file
        text_file_name, text_feature = text_features[i]  # Renamed to avoid shadowing
        audio_file_name, audio_feature = audio_features[i]  # Renamed to avoid shadowing
        video_file_name, video_feature = video_features[i]  # Renamed to avoid shadowing

        # print(f"Processing file {text_file_name}")

        # Check if any features are missing
        if text_feature is None or audio_feature is None or video_feature is None:
            print(f"Skipping file {i + 1}/{len(text_features)}: Missing features for {text_file_name}, {audio_file_name}, {video_file_name}")
            continue  # Skip to the next iteration

        # print("Text file name:", text_file_name)
        # print("Audio file name:", audio_file_name)
        # print("Video file name:", video_file_name)

        print("Text features shape:", text_feature.shape)
        print("Audio features shape:", audio_feature.shape)
        print("Video features shape:", video_feature.shape)

        # Reshape features
        audio_feature = audio_feature.squeeze(0)  # Changed from audio_features to audio_feature
        text_feature = text_feature.unsqueeze(0)  # Changed from text_features to text_feature

        # print("text_features shape:", text_feature.shape)
        # print("audio_features shape:", audio_feature.shape)
        # print("video_features shape:", video_feature.shape, '\n')


        with torch.no_grad():
            # Cross-Attention for every possible pair
            text_video = PairCrossAttention(text_feature, video_feature)
            text_audio = PairCrossAttention(text_feature, audio_feature)
            audio_video = PairCrossAttention(audio_feature, video_feature)
            audio_text = PairCrossAttention(audio_feature, text_feature)
            video_audio = PairCrossAttention(video_feature, audio_feature)
            video_text = PairCrossAttention(video_feature, text_feature)

            # print("video_audio shape:", video_audio.shape)
            # print("video_text shape:", video_text.shape)
            # print("audio_video shape:", audio_video.shape)
            # print("audio_text shape:", audio_text.shape)
            # print("text_video shape:", text_video.shape)
            # print("text_audio shape:", text_audio.shape, '\n')

            # Combine Cross-Attention outputs using Hadamard product
            text_combined = HadamardProduct(text_video, text_audio)
            audio_combined = HadamardProduct(audio_video, audio_text)
            video_combined = HadamardProduct(video_audio, video_text)

            # Fusion using Embracement Layer
            d_in = video_combined.shape[-1] + audio_combined.shape[-1] + text_combined.shape[-1]
            embracement_layer = EmbracementLayer(d_in, d_in)
            
            # Fused features for the current file
            fused_features = embracement_layer(video_combined[-1], audio_combined[-1], text_combined[-1])
            
            print("Fused Features Shape:", fused_features.shape, '\n')

            # Append the fused features and the corresponding label to the lists
            fused_features_list.append(fused_features)
            label = id_label_df.iloc[i]['Label']  # Assuming you have a column 'Label'
            labels_list.append(label)

        del text_feature, audio_feature, video_feature
        del text_video, text_audio, audio_video, audio_text, video_audio, video_text
        
# Stack all fused features into a tensor for training
fused_features_tensor = torch.stack(fused_features_list)

# Convert labels to tensor
label_map = {'red': 1, 'green': 0}  # Adjust if your labels differ
labels_tensor = torch.tensor([label_map[label] for label in labels_list], dtype=torch.float32)
# Out:
# Batch: 0
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([95, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([124, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([136, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([116, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([113, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([126, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([131, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([134, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([140, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([147, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([139, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([144, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([98, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([162, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([104, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([151, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([12, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([105, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([67, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([108, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([88, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([191, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([82, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([101, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([102, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([244, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Batch: 32
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([95, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([124, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([136, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([116, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([113, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([126, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([131, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([134, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([140, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([147, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([139, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([144, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([98, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([162, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([104, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([151, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([12, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([105, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([67, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([108, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([88, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([191, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([82, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([101, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([102, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([244, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Batch: 64
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([95, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([124, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([136, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([116, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([113, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([126, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([131, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([134, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([140, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([147, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([139, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([144, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([98, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([162, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([104, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([151, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([12, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([105, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([67, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([108, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([88, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([191, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([82, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([101, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([102, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([244, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Batch: 96
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([95, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([124, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([136, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([116, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([113, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([126, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([131, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([134, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([140, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([147, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([139, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([144, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([98, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([162, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([104, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([151, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([12, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([105, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([67, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([108, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([88, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([191, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([82, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([101, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([102, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([244, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Batch: 128
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([95, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([124, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([136, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([116, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([113, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([126, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([131, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([134, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([140, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([147, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([139, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([144, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([98, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([162, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([104, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([151, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([12, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([105, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([67, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([108, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([88, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([191, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([82, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([101, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([102, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([244, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Batch: 160
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([95, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([124, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([136, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([116, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([113, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([126, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([131, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([134, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([140, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([147, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([139, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([144, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([98, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([162, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([104, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([151, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([12, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([105, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([67, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([108, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([88, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([191, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([82, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([101, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([102, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([244, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Batch: 192
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([95, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([124, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([136, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([116, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([113, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([126, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([131, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([134, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([140, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([147, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([139, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([144, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([98, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([162, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([104, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([151, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([12, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([105, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([67, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([108, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([88, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([191, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([82, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([101, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([102, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([244, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Batch: 224
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([95, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([124, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([136, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([116, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([113, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([126, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([131, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([134, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([140, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([147, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([139, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([144, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([98, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([162, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([104, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([151, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([12, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([105, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([67, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([108, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([88, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([191, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([82, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([101, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([102, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([244, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Batch: 256
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([95, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([124, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([136, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([116, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([113, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([126, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([131, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([134, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([140, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([147, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([139, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([144, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# ...
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([139, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([144, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([98, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([162, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([104, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([151, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([12, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([105, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([67, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([108, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([88, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([191, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([82, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([101, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([102, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([244, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Batch: 1280
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([95, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([124, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([136, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([116, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([113, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([126, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([131, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([134, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([140, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([147, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([139, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([144, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([98, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([162, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([104, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([151, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([12, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([105, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([67, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([108, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([88, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([191, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([82, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([101, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([102, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([244, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Batch: 1312
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([95, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([124, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([136, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([116, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([113, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([126, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([131, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([134, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([140, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([147, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([139, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([144, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([98, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([162, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([104, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([151, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([12, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([105, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([67, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([108, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([88, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([191, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([82, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([101, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([102, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([244, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Batch: 1344
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([95, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([124, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([136, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([116, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([113, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([126, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([131, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([134, 768])
# Fused Features Shape: torch.Size([2304])

# %%
# Splitting data for training, validation, and testing
train_df, val_test_df, train_labels, val_test_labels = train_test_split(
    fused_features_tensor, labels_tensor, test_size=0.3, random_state=42)

# Further splitting remaining set into validation and test sets
val_df, test_df, val_labels, test_labels = train_test_split(
    val_test_df, val_test_labels, test_size=0.5, random_state=42)

# Create DataLoaders
train_loader = DataLoader(list(zip(train_df, train_labels)), batch_size=32, shuffle=True)
val_loader = DataLoader(list(zip(val_df, val_labels)), batch_size=32, shuffle=False)
test_loader = DataLoader(list(zip(test_df, test_labels)), batch_size=32, shuffle=False)

# %%
if __name__ == "__main__":
    torch.manual_seed(42)

    # Check for device availability
    if torch.backends.mps.is_available():
        device = torch.device("mps")
    else:
        device = torch.device("cpu")

    # Input dimension based on fused features tensor
    input_dim = fused_features_tensor.shape[1]  # Adjust if necessary
    dense_layer = DenseLayer(input_size=input_dim).to(device)  # Initialize and move the dense layer to the correct device

    # Define the loss function and optimizer
    criterion = BCELoss()  # Use appropriate loss function
    optimizer = get_optimizer(dense_layer.parameters())  # Pass only the dense layer parameters

    # Training loop
    num_epochs = 10  # Set the number of epochs you want to train for

    for epoch in range(num_epochs):
        print(f"Epoch {epoch + 1}/{num_epochs}")

        # Ensure you have a dataloader that yields inputs and targets
        train_loss = train_model(dense_layer=dense_layer, dataloader=train_loader, criterion=criterion, optimizer=optimizer, device=device)
        
        # Validate model
        val_loss, precision, recall, f1_score = evaluate_model(dense_layer=dense_layer, dataloader=val_loader, criterion=criterion, device=device)

        print(f"Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")
        print("-" * 30)
    
    # Testing the model
    print("Testing the model on the test set...")
    test_loss, test_precision, test_recall, test_f1_score = test_model(dense_layer=dense_layer, dataloader=test_loader, criterion=criterion, device=device)
# Out:
# Epoch 1/10
# Evaluation Loss: 0.6955
# Precision: 0.3175
# Recall: 0.2597
# F1 Score: 0.2857
# Training Loss: 0.6634, Validation Loss: 0.6955
# ------------------------------
# Epoch 2/10
# Evaluation Loss: 0.6791
# Precision: 0.3793
# Recall: 0.1429
# F1 Score: 0.2075
# Training Loss: 0.5666, Validation Loss: 0.6791
# ------------------------------
# Epoch 3/10
# Evaluation Loss: 0.6787
# Precision: 0.4062
# Recall: 0.1688
# F1 Score: 0.2385
# Training Loss: 0.4984, Validation Loss: 0.6787
# ------------------------------
# Epoch 4/10
# Evaluation Loss: 0.6935
# Precision: 0.3750
# Recall: 0.2727
# F1 Score: 0.3158
# Training Loss: 0.4475, Validation Loss: 0.6935
# ------------------------------
# Epoch 5/10
# Evaluation Loss: 0.6911
# Precision: 0.3333
# Recall: 0.0779
# F1 Score: 0.1263
# Training Loss: 0.4018, Validation Loss: 0.6911
# ------------------------------
# Epoch 6/10
# Evaluation Loss: 0.6897
# Precision: 0.4706
# Recall: 0.2078
# F1 Score: 0.2883
# Training Loss: 0.3653, Validation Loss: 0.6897
# ------------------------------
# Epoch 7/10
# Evaluation Loss: 0.7101
# Precision: 0.4000
# Recall: 0.1039
# F1 Score: 0.1649
# Training Loss: 0.3295, Validation Loss: 0.7101
# ------------------------------
# Epoch 8/10
# Evaluation Loss: 0.7082
# Precision: 0.4688
# Recall: 0.1948
# F1 Score: 0.2752
# Training Loss: 0.3099, Validation Loss: 0.7082
# ------------------------------
# Epoch 9/10
# Evaluation Loss: 0.7152
# Precision: 0.4000
# Recall: 0.2597
# F1 Score: 0.3150
# Training Loss: 0.2832, Validation Loss: 0.7152
# ------------------------------
# Epoch 10/10
# Evaluation Loss: 0.7264
# Precision: 0.4516
# Recall: 0.1818
# F1 Score: 0.2593
# Training Loss: 0.2661, Validation Loss: 0.7264
# ------------------------------
# Testing the model on the test set...
# Test Loss: 0.7809
# Test Precision: 0.1250
# Test Recall: 0.0448
# Test F1 Score: 0.0659

# %% [markdown]
# ### K-Fold Evaluation

# %%
def cross_validate_model(
    fused_features_tensor, 
    labels_tensor, 
    num_folds, 
    num_epochs, 
    batch_size, 
    learning_rate,
    device=None
):
    # Set device configuration
    if device is None:
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Device: {device}")
    
    # Create a TensorDataset from the features and labels
    dataset = TensorDataset(fused_features_tensor, labels_tensor)

    # Initialize KFold
    kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)

    # lists to store metrics for each fold
    fold_losses = []
    fold_precisions = []
    fold_recalls = []
    fold_f1_scores = []

    for fold, (train_idx, val_idx) in enumerate(kf.split(dataset)):
        print(f"Fold {fold + 1}/{num_folds}")
     
        # Create data loaders for the train and validation sets
        train_sampler = torch.utils.data.SubsetRandomSampler(train_idx)
        val_sampler = torch.utils.data.SubsetRandomSampler(val_idx)
        
        train_dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, sampler=train_sampler)
        val_dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, sampler=val_sampler)

        # Initialize model, criterion, and optimizer
        dense_layer = DenseLayer(input_size=input_dim).to(device)  # Initialize and move the dense layer to the correct device  # Initialize your model here
        criterion = BCEWithLogits()  # Example loss for binary classification
        optimizer = get_optimizer(dense_layer.parameters(), lr=learning_rate)

        # Train the model for the specified number of epochs
        for epoch in range(num_epochs):
            print(f"Epoch {epoch + 1}/{num_epochs}")
        
            train_loss = train_model(dense_layer, train_dataloader, criterion, optimizer, device)
            val_loss, precision, recall, f1_score = evaluate_model(dense_layer, val_dataloader, criterion, device)
            print(f"Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")
            
            
        # Store the validation metrics for this fold
        fold_losses.append(val_loss)
        fold_precisions.append(precision)
        fold_recalls.append(recall)
        fold_f1_scores.append(f1_score)

    # Calculate the average metrics across all folds
    avg_loss = np.mean(fold_losses)
    avg_precision = np.mean(fold_precisions)
    avg_recall = np.mean(fold_recalls)
    avg_f1_score = np.mean(fold_f1_scores)

    print("\nK-Fold Cross-Validation Results:")
    print(f"Average Loss: {avg_loss:.4f}")
    print(f"Average Precision: {avg_precision:.4f}")
    print(f"Average Recall: {avg_recall:.4f}")
    print(f"Average F1 Score: {avg_f1_score:.4f}")

    # Return the average metrics for further analysis or logging
    return {
        "average_loss": avg_loss,
        "average_precision": avg_precision,
        "average_recall": avg_recall,
        "average_f1_score": avg_f1_score
    }

# %%
# Run k-fold cross-validation   
results = cross_validate_model(
    fused_features_tensor, 
    labels_tensor, 
    num_folds=10,
    num_epochs=10,
    batch_size=32,
    learning_rate=1e-5,
)
# Out:
# Device: cuda
# Fold 1/10
# Epoch 1/10
# Evaluation Loss: 0.7576
# Precision: 0.1818
# Recall: 0.0400
# F1 Score: 0.0656
# Training Loss: 0.7808, Validation Loss: 0.7576
# Epoch 2/10
# Evaluation Loss: 0.7448
# Precision: 0.3333
# Recall: 0.0200
# F1 Score: 0.0377
# Training Loss: 0.7708, Validation Loss: 0.7448
# Epoch 3/10
# Evaluation Loss: 0.7341
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7497, Validation Loss: 0.7341
# Epoch 4/10
# Evaluation Loss: 0.7270
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7444, Validation Loss: 0.7270
# Epoch 5/10
# Evaluation Loss: 0.7254
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7361, Validation Loss: 0.7254
# Epoch 6/10
# Evaluation Loss: 0.7256
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7239, Validation Loss: 0.7256
# Epoch 7/10
# Evaluation Loss: 0.7156
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7235, Validation Loss: 0.7156
# Epoch 8/10
# Evaluation Loss: 0.7157
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7205, Validation Loss: 0.7157
# Epoch 9/10
# Evaluation Loss: 0.7094
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7132, Validation Loss: 0.7094
# Epoch 10/10
# Evaluation Loss: 0.7079
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7099, Validation Loss: 0.7079
# Fold 2/10
# Epoch 1/10
# Evaluation Loss: 0.7509
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7569, Validation Loss: 0.7509
# Epoch 2/10
# Evaluation Loss: 0.7341
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7503, Validation Loss: 0.7341
# Epoch 3/10
# Evaluation Loss: 0.7258
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7385, Validation Loss: 0.7258
# Epoch 4/10
# Evaluation Loss: 0.7178
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7329, Validation Loss: 0.7178
# Epoch 5/10
# Evaluation Loss: 0.7223
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7210, Validation Loss: 0.7223
# Epoch 6/10
# Evaluation Loss: 0.7061
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7201, Validation Loss: 0.7061
# Epoch 7/10
# Evaluation Loss: 0.7128
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7166, Validation Loss: 0.7128
# Epoch 8/10
# Evaluation Loss: 0.7052
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7097, Validation Loss: 0.7052
# Epoch 9/10
# Evaluation Loss: 0.7066
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7102, Validation Loss: 0.7066
# Epoch 10/10
# Evaluation Loss: 0.6998
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7088, Validation Loss: 0.6998
# Fold 3/10
# Epoch 1/10
# Evaluation Loss: 0.8011
# Precision: 0.2903
# Recall: 0.2195
# F1 Score: 0.2500
# Training Loss: 0.7960, Validation Loss: 0.8011
# Epoch 2/10
# Evaluation Loss: 0.7909
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7776, Validation Loss: 0.7909
# Epoch 3/10
# Evaluation Loss: 0.7755
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7622, Validation Loss: 0.7755
# Epoch 4/10
# Evaluation Loss: 0.7539
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7433, Validation Loss: 0.7539
# Epoch 5/10
# Evaluation Loss: 0.7406
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7403, Validation Loss: 0.7406
# Epoch 6/10
# Evaluation Loss: 0.7429
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7336, Validation Loss: 0.7429
# Epoch 7/10
# Evaluation Loss: 0.7352
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7227, Validation Loss: 0.7352
# Epoch 8/10
# Evaluation Loss: 0.7334
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7216, Validation Loss: 0.7334
# Epoch 9/10
# Evaluation Loss: 0.7271
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7182, Validation Loss: 0.7271
# Epoch 10/10
# Evaluation Loss: 0.7263
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7157, Validation Loss: 0.7263
# Fold 4/10
# Epoch 1/10
# Evaluation Loss: 0.7578
# Precision: 0.3200
# Recall: 0.3200
# F1 Score: 0.3200
# Training Loss: 0.8008, Validation Loss: 0.7578
# Epoch 2/10
# Evaluation Loss: 0.7727
# Precision: 0.3333
# Recall: 0.1200
# F1 Score: 0.1765
# Training Loss: 0.7754, Validation Loss: 0.7727
# Epoch 3/10
# Evaluation Loss: 0.7439
# Precision: 0.3333
# Recall: 0.0200
# F1 Score: 0.0377
# Training Loss: 0.7655, Validation Loss: 0.7439
# Epoch 4/10
# Evaluation Loss: 0.7414
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7485, Validation Loss: 0.7414
# Epoch 5/10
# Evaluation Loss: 0.7393
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7458, Validation Loss: 0.7393
# Epoch 6/10
# Evaluation Loss: 0.7182
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7330, Validation Loss: 0.7182
# Epoch 7/10
# Evaluation Loss: 0.7241
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7278, Validation Loss: 0.7241
# Epoch 8/10
# Evaluation Loss: 0.7230
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7239, Validation Loss: 0.7230
# Epoch 9/10
# Evaluation Loss: 0.7197
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7176, Validation Loss: 0.7197
# Epoch 10/10
# Evaluation Loss: 0.7136
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7162, Validation Loss: 0.7136
# Fold 5/10
# Epoch 1/10
# Evaluation Loss: 0.8355
# Precision: 0.2727
# Recall: 0.2571
# F1 Score: 0.2647
# Training Loss: 0.7933, Validation Loss: 0.8355
# Epoch 2/10
# Evaluation Loss: 0.8087
# Precision: 0.2857
# Recall: 0.0571
# F1 Score: 0.0952
# Training Loss: 0.7814, Validation Loss: 0.8087
# Epoch 3/10
# Evaluation Loss: 0.7687
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7659, Validation Loss: 0.7687
# Epoch 4/10
# Evaluation Loss: 0.7662
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7448, Validation Loss: 0.7662
# Epoch 5/10
# Evaluation Loss: 0.7563
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7381, Validation Loss: 0.7563
# Epoch 6/10
# Evaluation Loss: 0.7343
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7341, Validation Loss: 0.7343
# Epoch 7/10
# Evaluation Loss: 0.7406
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7252, Validation Loss: 0.7406
# Epoch 8/10
# Evaluation Loss: 0.7398
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7188, Validation Loss: 0.7398
# Epoch 9/10
# Evaluation Loss: 0.7269
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7156, Validation Loss: 0.7269
# Epoch 10/10
# Evaluation Loss: 0.7178
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7155, Validation Loss: 0.7178
# Fold 6/10
# Epoch 1/10
# Evaluation Loss: 0.7798
# Precision: 0.3919
# Recall: 0.5577
# F1 Score: 0.4603
# Training Loss: 0.8190, Validation Loss: 0.7798
# Epoch 2/10
# Evaluation Loss: 0.7547
# Precision: 0.3226
# Recall: 0.1923
# F1 Score: 0.2410
# Training Loss: 0.7946, Validation Loss: 0.7547
# Epoch 3/10
# Evaluation Loss: 0.7335
# Precision: 0.2857
# Recall: 0.0385
# F1 Score: 0.0678
# Training Loss: 0.7840, Validation Loss: 0.7335
# Epoch 4/10
# Evaluation Loss: 0.7411
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7689, Validation Loss: 0.7411
# Epoch 5/10
# Evaluation Loss: 0.7392
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7538, Validation Loss: 0.7392
# Epoch 6/10
# Evaluation Loss: 0.7198
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7403, Validation Loss: 0.7198
# Epoch 7/10
# Evaluation Loss: 0.7167
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7351, Validation Loss: 0.7167
# Epoch 8/10
# Evaluation Loss: 0.7198
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7249, Validation Loss: 0.7198
# Epoch 9/10
# Evaluation Loss: 0.7049
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7200, Validation Loss: 0.7049
# Epoch 10/10
# Evaluation Loss: 0.7104
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7203, Validation Loss: 0.7104
# Fold 7/10
# Epoch 1/10
# Evaluation Loss: 0.7807
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7729, Validation Loss: 0.7807
# Epoch 2/10
# Evaluation Loss: 0.7574
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7593, Validation Loss: 0.7574
# Epoch 3/10
# Evaluation Loss: 0.7354
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7428, Validation Loss: 0.7354
# Epoch 4/10
# Evaluation Loss: 0.7225
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7349, Validation Loss: 0.7225
# Epoch 5/10
# Evaluation Loss: 0.7143
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7278, Validation Loss: 0.7143
# Epoch 6/10
# Evaluation Loss: 0.7133
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7240, Validation Loss: 0.7133
# Epoch 7/10
# Evaluation Loss: 0.7114
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7190, Validation Loss: 0.7114
# Epoch 8/10
# Evaluation Loss: 0.7140
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7157, Validation Loss: 0.7140
# Epoch 9/10
# Evaluation Loss: 0.7075
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7122, Validation Loss: 0.7075
# Epoch 10/10
# Evaluation Loss: 0.7076
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7095, Validation Loss: 0.7076
# Fold 8/10
# Epoch 1/10
# Evaluation Loss: 0.7808
# Precision: 0.3214
# Recall: 0.1875
# F1 Score: 0.2368
# Training Loss: 0.7983, Validation Loss: 0.7808
# Epoch 2/10
# Evaluation Loss: 0.7538
# Precision: 0.2500
# Recall: 0.0625
# F1 Score: 0.1000
# Training Loss: 0.7797, Validation Loss: 0.7538
# Epoch 3/10
# Evaluation Loss: 0.7590
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7604, Validation Loss: 0.7590
# Epoch 4/10
# Evaluation Loss: 0.7452
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7511, Validation Loss: 0.7452
# Epoch 5/10
# Evaluation Loss: 0.7313
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7411, Validation Loss: 0.7313
# Epoch 6/10
# Evaluation Loss: 0.7297
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7303, Validation Loss: 0.7297
# Epoch 7/10
# Evaluation Loss: 0.7229
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7266, Validation Loss: 0.7229
# Epoch 8/10
# Evaluation Loss: 0.7269
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7220, Validation Loss: 0.7269
# Epoch 9/10
# Evaluation Loss: 0.7136
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7185, Validation Loss: 0.7136
# Epoch 10/10
# Evaluation Loss: 0.7103
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7138, Validation Loss: 0.7103
# Fold 9/10
# Epoch 1/10
# Evaluation Loss: 0.7905
# Precision: 0.2500
# Recall: 0.0889
# F1 Score: 0.1311
# Training Loss: 0.7907, Validation Loss: 0.7905
# Epoch 2/10
# Evaluation Loss: 0.7869
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7670, Validation Loss: 0.7869
# Epoch 3/10
# Evaluation Loss: 0.7497
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7568, Validation Loss: 0.7497
# Epoch 4/10
# Evaluation Loss: 0.7526
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7455, Validation Loss: 0.7526
# Epoch 5/10
# Evaluation Loss: 0.7339
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7335, Validation Loss: 0.7339
# Epoch 6/10
# Evaluation Loss: 0.7351
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7292, Validation Loss: 0.7351
# Epoch 7/10
# Evaluation Loss: 0.7274
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7201, Validation Loss: 0.7274
# Epoch 8/10
# Evaluation Loss: 0.7186
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7189, Validation Loss: 0.7186
# Epoch 9/10
# Evaluation Loss: 0.7177
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7147, Validation Loss: 0.7177
# Epoch 10/10
# Evaluation Loss: 0.7139
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7110, Validation Loss: 0.7139
# Fold 10/10
# Epoch 1/10
# Evaluation Loss: 0.7952
# Precision: 0.3600
# Recall: 0.2143
# F1 Score: 0.2687
# Training Loss: 0.7989, Validation Loss: 0.7952
# Epoch 2/10
# Evaluation Loss: 0.7901
# Precision: 0.4000
# Recall: 0.0952
# F1 Score: 0.1538
# Training Loss: 0.7737, Validation Loss: 0.7901
# Epoch 3/10
# Evaluation Loss: 0.7735
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7592, Validation Loss: 0.7735
# Epoch 4/10
# Evaluation Loss: 0.7566
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7519, Validation Loss: 0.7566
# Epoch 5/10
# Evaluation Loss: 0.7467
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7382, Validation Loss: 0.7467
# Epoch 6/10
# Evaluation Loss: 0.7281
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7334, Validation Loss: 0.7281
# Epoch 7/10
# Evaluation Loss: 0.7276
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7228, Validation Loss: 0.7276
# Epoch 8/10
# Evaluation Loss: 0.7246
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7184, Validation Loss: 0.7246
# Epoch 9/10
# Evaluation Loss: 0.7250
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7185, Validation Loss: 0.7250
# Epoch 10/10
# Evaluation Loss: 0.7199
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.7135, Validation Loss: 0.7199
#
# K-Fold Cross-Validation Results:
# Average Loss: 0.7128
# Average Precision: 0.0000
# Average Recall: 0.0000
# Average F1 Score: 0.0000
