# %%
import sys
import os
import numpy as np
import pandas as pd
import torch
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset, Dataset, Subset
from torcheval.metrics import BinaryPrecision, BinaryRecall, BinaryF1Score
from sklearn.model_selection import train_test_split, KFold

# %%
# Append the path for module imports
sys.path.append('../')

# Import custom modules
from modules.cross_attentionb import CrossAttentionB
from modules.dataloader import load_npy_files
from modules.classifier import DenseLayer, BCELoss, BCEWithLogits

# %% [markdown]
# ### Data Loading

# %%
# Load the labels DataFrame
id_label_df = pd.read_excel('../misc/MM-Trailer_dataset.xlsx')

# Define the directories
text_features_dir = 'C:\\Users\\edjin\\OneDrive\\Documents\\Programming Files\\Thesis\\SMCA\\misc\\textStream_BERT\\feature_vectors\\feature_vectors'
audio_features_dir = 'C:\\Users\\edjin\\OneDrive\\Documents\\Programming Files\\Thesis\\SMCA\\misc\\audio_fe\\logmel_spectrograms'
video_features_dir = 'C:\\Users\\edjin\\OneDrive\\Documents\\Programming Files\\Thesis\\SMCA\\misc\\visualStream_ViT\\feature_vectors'

# Load the feature vectors from each directory
text_features = load_npy_files(text_features_dir)
audio_features = load_npy_files(audio_features_dir)
video_features = load_npy_files(video_features_dir)

print(f"Number of text feature vectors loaded: {len(text_features)}")
print(f"Number of audio feature vectors loaded: {len(audio_features)}")
print(f"Number of video feature vectors loaded: {len(video_features)}")
# Out:
# Number of text feature vectors loaded: 1353
# Number of audio feature vectors loaded: 1353
# Number of video feature vectors loaded: 1353

# %%
# Cross Attention Function
def PairCrossAttention(modalityAlpha, modalityBeta, d_out_kq=768, d_out_v=768):
    cross_attn = CrossAttentionB(modalityAlpha.shape[-1], modalityBeta.shape[-1], d_out_kq, d_out_v)
    modalityAlphaBeta = cross_attn(modalityAlpha, modalityBeta)
    return modalityAlphaBeta

# %%
def HadamardProduct(tensor1, tensor2):
    # Ensure both tensors have the same shape
    if tensor1.shape != tensor2.shape:
        raise ValueError("Tensors must have the same shape for Hadamard product.")
    
    # Compute the Hadamard product
    return tensor1 * tensor2

# %%
class EmbracementLayer(nn.Module):
    def __init__(self, d_in, d_out):
        super(EmbracementLayer, self).__init__()
        self.fc = nn.Linear(d_in, d_out)
        self.norm = nn.LayerNorm(d_out)
        self.activation = nn.ReLU()

    def forward(self, video_features, audio_features, text_features):
        # Concatenate features along the last dimension
        combined_features = torch.cat([video_features, audio_features, text_features], dim=-1)
        
        # Apply linear transformation
        transformed_features = self.fc(combined_features)
        
        # Apply normalization and activation
        norm_features = self.norm(transformed_features)
        output = self.activation(norm_features)
        
        return output

# %% [markdown]
# ### Model Training

# %%
def get_optimizer(parameters, lr=1e-3):
    # Create an optimizer, for example, Adam
    return optim.Adam(parameters, lr=lr)

# %%
def train_model(dense_layer, dataloader, criterion, optimizer, device):
    dense_layer.train()  # Set the model to training mode
    total_loss = 0.0

    for batch in dataloader:
        # Assuming batch is a tuple (fused_features, targets)
        fused_features, targets = batch

        # Move tensors to the specified device
        fused_features = fused_features.to(device)
        targets = targets.to(device)

        # Clear gradients
        optimizer.zero_grad()

        # Pass the fused features through the dense layer
        predictions = dense_layer(fused_features).view(-1)    # Ensure correct shape

        # Compute loss
        loss = criterion(predictions, targets)

        # Backward pass and optimization
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    return total_loss / len(dataloader)

# %%
def evaluate_model(dense_layer, dataloader, criterion, device):
    dense_layer.eval()
    total_loss = 0

    # Initialize the metrics for binary classification
    precision_metric = BinaryPrecision().to(device)
    recall_metric = BinaryRecall().to(device)
    f1_metric = BinaryF1Score().to(device)
    
    with torch.no_grad():
        for fused_features, targets in dataloader:
            fused_features, targets = (
                fused_features.to(device),  # Use fused features directly
                targets.to(device).squeeze()
            )

            # Pass the fused features through the dense layer
            predictions = dense_layer(fused_features).view(-1)
            
            # Compute loss
            loss = criterion(predictions, targets)
            total_loss += loss.item()

            # Apply threshold to get binary predictions
            preds = (predictions > 0.5).float()
            
            # Update the precision, recall, and F1 score metrics
            precision_metric.update(preds.long(), targets.long())
            recall_metric.update(preds.long(), targets.long())
            f1_metric.update(preds.long(), targets.long())

    # Compute precision, recall, and F1 score
    precision = precision_metric.compute().item()
    recall = recall_metric.compute().item()
    f1_score = f1_metric.compute().item()

    average_loss = total_loss / len(dataloader)

    print(f"Evaluation Loss: {average_loss:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1_score:.4f}")
    
    return average_loss, precision, recall, f1_score

# %%
def test_model(dense_layer, dataloader, criterion, device):
    dense_layer.eval()  # Set the model to evaluation mode
    total_loss = 0

    # Initialize the metrics for binary classification
    precision_metric = BinaryPrecision().to(device)
    recall_metric = BinaryRecall().to(device)
    f1_metric = BinaryF1Score().to(device)

    with torch.no_grad():
        for fused_features, targets in dataloader:
            fused_features, targets = (
                fused_features.to(device),  # Move fused features to device
                targets.to(device).squeeze()  # Ensure targets are the correct shape
            )

            # Pass the fused features through the dense layer
            predictions = dense_layer(fused_features).view(-1)  
            
            # Compute loss
            loss = criterion(predictions, targets)
            total_loss += loss.item()

            # Apply threshold to get binary predictions
            preds = (predictions > 0.5).float()
            
            # Update the precision, recall, and F1 score metrics
            precision_metric.update(preds.long(), targets.long())
            recall_metric.update(preds.long(), targets.long())
            f1_metric.update(preds.long(), targets.long())

    # Compute precision, recall, and F1 score
    precision = precision_metric.compute().item()
    recall = recall_metric.compute().item()
    f1_score = f1_metric.compute().item()

    average_loss = total_loss / len(dataloader)

    print(f"Test Loss: {average_loss:.4f}")
    print(f"Test Precision: {precision:.4f}")
    print(f"Test Recall: {recall:.4f}")
    print(f"Test F1 Score: {f1_score:.4f}")

    return average_loss, precision, recall, f1_score

# %% [markdown]
# ### Fusion

# %%
# Initialize list to store fused features for each file
fused_features_list = []
labels_list = []
batch_size = 32  # Adjust based on your available memory

for batch_start in range(0, len(text_features), batch_size):
    batch_end = min(batch_start + batch_size, len(text_features))
    batch_text_features = text_features[batch_start:batch_end]
    batch_audio_features = audio_features[batch_start:batch_end]
    batch_video_features = video_features[batch_start:batch_end]
    print(f"Batch: {batch_start}")
    # Loop through all the files in the dataset
    for i in range(len(batch_text_features)):
        # Extract features for the current file
        text_file_name, text_feature = text_features[i]  # Renamed to avoid shadowing
        audio_file_name, audio_feature = audio_features[i]  # Renamed to avoid shadowing
        video_file_name, video_feature = video_features[i]  # Renamed to avoid shadowing

        # print(f"Processing file {text_file_name}")

        # Check if any features are missing
        if text_feature is None or audio_feature is None or video_feature is None:
            print(f"Skipping file {i + 1}/{len(text_features)}: Missing features for {text_file_name}, {audio_file_name}, {video_file_name}")
            continue  # Skip to the next iteration

        # print("Text file name:", text_file_name)
        # print("Audio file name:", audio_file_name)
        # print("Video file name:", video_file_name)

        print("Text features shape:", text_feature.shape)
        print("Audio features shape:", audio_feature.shape)
        print("Video features shape:", video_feature.shape)

        # Reshape features
        audio_feature = audio_feature.squeeze(0)  # Changed from audio_features to audio_feature
        text_feature = text_feature.unsqueeze(0)  # Changed from text_features to text_feature

        # print("text_features shape:", text_feature.shape)
        # print("audio_features shape:", audio_feature.shape)
        # print("video_features shape:", video_feature.shape, '\n')


        with torch.no_grad():
            # Cross-Attention for every possible pair
            text_video = PairCrossAttention(text_feature, video_feature)
            text_audio = PairCrossAttention(text_feature, audio_feature)
            audio_video = PairCrossAttention(audio_feature, video_feature)
            audio_text = PairCrossAttention(audio_feature, text_feature)
            video_audio = PairCrossAttention(video_feature, audio_feature)
            video_text = PairCrossAttention(video_feature, text_feature)

            # print("video_audio shape:", video_audio.shape)
            # print("video_text shape:", video_text.shape)
            # print("audio_video shape:", audio_video.shape)
            # print("audio_text shape:", audio_text.shape)
            # print("text_video shape:", text_video.shape)
            # print("text_audio shape:", text_audio.shape, '\n')

            # Combine Cross-Attention outputs using Hadamard product
            text_combined = HadamardProduct(text_video, text_audio)
            audio_combined = HadamardProduct(audio_video, audio_text)
            video_combined = HadamardProduct(video_audio, video_text)

            # Fusion using Embracement Layer
            d_in = video_combined.shape[-1] + audio_combined.shape[-1] + text_combined.shape[-1]
            embracement_layer = EmbracementLayer(d_in, d_in)
            
            # Fused features for the current file
            fused_features = embracement_layer(video_combined[-1], audio_combined[-1], text_combined[-1])
            
            print("Fused Features Shape:", fused_features.shape, '\n')

            # Append the fused features and the corresponding label to the lists
            fused_features_list.append(fused_features)
            label = id_label_df.iloc[i]['Label']  # Assuming you have a column 'Label'
            labels_list.append(label)

        del text_feature, audio_feature, video_feature
        del text_video, text_audio, audio_video, audio_text, video_audio, video_text
        
# Stack all fused features into a tensor for training
fused_features_tensor = torch.stack(fused_features_list)

# Convert labels to tensor
label_map = {'red': 1, 'green': 0}  # Adjust if your labels differ
labels_tensor = torch.tensor([label_map[label] for label in labels_list], dtype=torch.float32)
# Out:
# Batch: 0
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([95, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([124, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([136, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([116, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([113, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([126, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([131, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([134, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([140, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([147, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([139, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([144, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([98, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([162, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([104, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([151, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([12, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([105, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([67, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([108, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([88, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([191, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([82, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([101, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([102, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([244, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Batch: 32
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([95, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([124, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([136, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([116, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([113, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([126, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([131, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([134, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([140, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([147, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([139, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([144, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([98, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([162, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([104, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([151, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([12, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([105, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([67, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([108, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([88, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([191, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([82, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([101, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([102, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([244, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Batch: 64
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([95, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([124, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([136, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([116, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([113, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([126, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([131, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([134, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([140, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([147, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([139, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([144, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([98, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([162, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([104, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([151, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([12, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([105, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([67, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([108, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([88, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([191, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([82, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([101, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([102, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([244, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Batch: 96
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([95, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([124, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([136, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([116, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([113, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([126, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([131, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([134, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([140, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([147, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([139, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([144, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([98, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([162, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([104, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([151, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([12, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([105, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([67, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([108, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([88, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([191, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([82, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([101, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([102, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([244, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Batch: 128
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([95, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([124, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([136, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([116, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([113, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([126, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([131, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([134, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([140, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([147, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([139, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([144, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([98, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([162, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([104, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([151, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([12, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([105, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([67, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([108, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([88, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([191, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([82, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([101, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([102, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([244, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Batch: 160
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([95, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([124, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([136, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([116, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([113, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([126, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([131, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([134, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([140, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([147, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([139, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([144, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([98, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([162, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([104, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([151, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([12, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([105, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([67, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([108, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([88, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([191, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([82, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([101, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([102, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([244, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Batch: 192
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([95, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([124, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([136, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([116, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([113, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([126, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([131, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([134, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([140, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([147, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([139, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([144, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([98, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([162, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([104, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([151, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([12, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([105, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([67, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([108, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([88, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([191, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([82, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([101, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([102, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([244, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Batch: 224
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([95, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([124, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([136, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([116, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([113, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([126, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([131, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([134, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([140, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([147, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([139, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([144, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([98, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([162, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([104, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([151, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([12, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([105, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([67, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([108, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([88, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([191, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([82, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([101, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([102, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([244, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Batch: 256
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([95, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([124, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([136, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([116, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([113, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([126, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([131, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([134, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([140, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([147, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([139, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([144, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# ...
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([139, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([144, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([98, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([162, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([104, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([151, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([12, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([105, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([67, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([108, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([88, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([191, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([82, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([101, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([102, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([244, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Batch: 1280
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([95, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([124, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([136, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([116, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([113, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([126, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([131, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([134, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([140, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([147, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([139, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([144, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([98, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([162, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([104, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([151, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([12, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([105, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([67, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([108, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([88, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([191, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([82, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([101, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([102, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([244, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Batch: 1312
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([95, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([124, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([136, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([116, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([113, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([126, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([131, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([134, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([140, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([147, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([139, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([144, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([98, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([162, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([104, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([151, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([12, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([105, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([67, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([108, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([88, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([191, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([82, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([101, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([102, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([244, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Batch: 1344
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([95, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([124, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([136, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([116, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([113, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([126, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([131, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([134, 768])
# Fused Features Shape: torch.Size([2304])

# %%
# Splitting data for training, validation, and testing
train_df, val_test_df, train_labels, val_test_labels = train_test_split(
    fused_features_tensor, labels_tensor, test_size=0.3, random_state=42)

# Further splitting remaining set into validation and test sets
val_df, test_df, val_labels, test_labels = train_test_split(
    val_test_df, val_test_labels, test_size=0.5, random_state=42)

# Create DataLoaders
train_loader = DataLoader(list(zip(train_df, train_labels)), batch_size=32, shuffle=True)
val_loader = DataLoader(list(zip(val_df, val_labels)), batch_size=32, shuffle=False)
test_loader = DataLoader(list(zip(test_df, test_labels)), batch_size=32, shuffle=False)

# %%
if __name__ == "__main__":
    torch.manual_seed(42)

    # Check for device availability
    if torch.backends.mps.is_available():
        device = torch.device("mps")
    else:
        device = torch.device("cpu")

    # Input dimension based on fused features tensor
    input_dim = fused_features_tensor.shape[1]  # Adjust if necessary
    dense_layer = DenseLayer(input_size=input_dim).to(device)  # Initialize and move the dense layer to the correct device

    # Define the loss function and optimizer
    criterion = BCELoss()  # Use appropriate loss function
    optimizer = get_optimizer(dense_layer.parameters())  # Pass only the dense layer parameters

    # Training loop
    num_epochs = 10  # Set the number of epochs you want to train for

    for epoch in range(num_epochs):
        print(f"Epoch {epoch + 1}/{num_epochs}")

        # Ensure you have a dataloader that yields inputs and targets
        train_loss = train_model(dense_layer=dense_layer, dataloader=train_loader, criterion=criterion, optimizer=optimizer, device=device)
        
        # Validate model
        val_loss, precision, recall, f1_score = evaluate_model(dense_layer=dense_layer, dataloader=val_loader, criterion=criterion, device=device)

        print(f"Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")
        print("-" * 30)
    
    # Testing the model
    print("Testing the model on the test set...")
    test_loss, test_precision, test_recall, test_f1_score = test_model(dense_layer=dense_layer, dataloader=test_loader, criterion=criterion, device=device)
# Out:
# Epoch 1/10
# Evaluation Loss: 0.7032
# Precision: 0.3721
# Recall: 0.4156
# F1 Score: 0.3926
# Training Loss: 0.6656, Validation Loss: 0.7032
# ------------------------------
# Epoch 2/10
# Evaluation Loss: 0.6751
# Precision: 0.2632
# Recall: 0.0649
# F1 Score: 0.1042
# Training Loss: 0.5709, Validation Loss: 0.6751
# ------------------------------
# Epoch 3/10
# Evaluation Loss: 0.6784
# Precision: 0.3125
# Recall: 0.0649
# F1 Score: 0.1075
# Training Loss: 0.5053, Validation Loss: 0.6784
# ------------------------------
# Epoch 4/10
# Evaluation Loss: 0.6866
# Precision: 0.3438
# Recall: 0.1429
# F1 Score: 0.2018
# Training Loss: 0.4581, Validation Loss: 0.6866
# ------------------------------
# Epoch 5/10
# Evaluation Loss: 0.7040
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.4122, Validation Loss: 0.7040
# ------------------------------
# Epoch 6/10
# Evaluation Loss: 0.6988
# Precision: 0.2778
# Recall: 0.0649
# F1 Score: 0.1053
# Training Loss: 0.3767, Validation Loss: 0.6988
# ------------------------------
# Epoch 7/10
# Evaluation Loss: 0.7192
# Precision: 0.2000
# Recall: 0.0260
# F1 Score: 0.0460
# Training Loss: 0.3415, Validation Loss: 0.7192
# ------------------------------
# Epoch 8/10
# Evaluation Loss: 0.7196
# Precision: 0.2941
# Recall: 0.0649
# F1 Score: 0.1064
# Training Loss: 0.3175, Validation Loss: 0.7196
# ------------------------------
# Epoch 9/10
# Evaluation Loss: 0.7218
# Precision: 0.3514
# Recall: 0.1688
# F1 Score: 0.2281
# Training Loss: 0.2955, Validation Loss: 0.7218
# ------------------------------
# Epoch 10/10
# Evaluation Loss: 0.7378
# Precision: 0.2857
# Recall: 0.0779
# F1 Score: 0.1224
# Training Loss: 0.2789, Validation Loss: 0.7378
# ------------------------------
# Testing the model on the test set...
# Test Loss: 0.7279
# Test Precision: 0.2500
# Test Recall: 0.0896
# Test F1 Score: 0.1319

# %% [markdown]
# ### K-Fold Evaluation

# %%
def cross_validate_model(
    fused_features_tensor, 
    labels_tensor, 
    num_folds, 
    num_epochs, 
    batch_size, 
    learning_rate,
    output_file,
    device=None
):
    # Set device configuration
    if device is None:
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Device: {device}")
  
    # Ensure the output directory exists
    output_dir = os.path.dirname(output_file)
    if output_dir and not os.path.exists(output_dir):
        os.makedirs(output_dir)  # Creates the directory if it does not exist
    
    # Create a TensorDataset from the features and labels
    dataset = TensorDataset(fused_features_tensor, labels_tensor)

    # Initialize KFold
    kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)

    # lists to store metrics for each fold
    fold_losses = []
    fold_precisions = []
    fold_recalls = []
    fold_f1_scores = []
    f1_scores_per_fold = []  # List to store F1 scores for each fold

    for fold, (train_idx, val_idx) in enumerate(kf.split(dataset)):
        print("-" * 50)
        print(f"------ Fold {fold + 1 }/{num_folds} ------")
     
        # Create data loaders for the train and validation sets
        train_sampler = torch.utils.data.SubsetRandomSampler(train_idx)
        val_sampler = torch.utils.data.SubsetRandomSampler(val_idx)
        
        train_dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, sampler=train_sampler)
        val_dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, sampler=val_sampler)

        # Initialize dense_layer, criterion, and optimizer
        dense_layer = DenseLayer(input_size=input_dim).to(device)  # Initialize and move the dense layer to the correct device  # Initialize your model here
        criterion = BCELoss()  # Example loss for binary classification
        optimizer = get_optimizer(dense_layer.parameters(), lr=learning_rate)

        # Train the model for the specified number of epochs
        for epoch in range(num_epochs):
            print(f"Epoch {epoch + 1}/{num_epochs}")
        
            train_loss = train_model(dense_layer, train_dataloader, criterion, optimizer, device)
            val_loss, precision, recall, f1_score = evaluate_model(dense_layer, val_dataloader, criterion, device)
            
            print(f"Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")
            print(f"Precision: {precision:.4f}, Recall: {recall:.4f}, F1 Score: {f1_score:.4f}")
            
        # Store the validation metrics for this fold
        print(f"Results for Fold {fold}: Validation Loss = {val_loss:.4f}, Precision = {precision:.4f}, Recall = {recall:.4f}, F1 Score = {f1_score:.4f}")
        fold_losses.append(val_loss)
        fold_precisions.append(precision)
        fold_recalls.append(recall)
        fold_f1_scores.append(f1_score)
        f1_scores_per_fold.append(f1_score)  # Save F1 score for the current fold

    # Calculate the average metrics across all folds
    avg_loss = np.mean(fold_losses)
    avg_precision = np.mean(fold_precisions)
    avg_recall = np.mean(fold_recalls)
    avg_f1_score = np.mean(fold_f1_scores)

    print("-" * 50)
    print("\nK-Fold Cross-Validation Results:")
    print(f"Average Loss: {avg_loss:.4f}")
    print(f"Average Precision: {avg_precision:.4f}")
    print(f"Average Recall: {avg_recall:.4f}")
    print(f"Average F1 Score: {avg_f1_score:.4f}")
    
    # Save F1 scores per fold to a .npy file
    np.save(output_file, np.array(f1_scores_per_fold))
    print(f"F1 scores per fold saved to {output_file}")

    return avg_loss, avg_precision, avg_recall, avg_f1_score

# %%
# Run k-fold cross-validation   
results = cross_validate_model(
    fused_features_tensor, 
    labels_tensor, 
    num_folds=10,
    num_epochs=10,
    batch_size=32,
    learning_rate=1e-4,
    output_file="results/simulParallel-Xie-F1_scores.npy"
)
# Out:
# Device: cuda
# --------------------------------------------------
# ------ Fold 1/10 ------
# Epoch 1/10
# Evaluation Loss: 0.6853
# Precision: 0.5000
# Recall: 0.0600
# F1 Score: 0.1071
# Training Loss: 0.6633, Validation Loss: 0.6853
# Precision: 0.5000, Recall: 0.0600, F1 Score: 0.1071
# Epoch 2/10
# Evaluation Loss: 0.6690
# Precision: 0.3333
# Recall: 0.0200
# F1 Score: 0.0377
# Training Loss: 0.6383, Validation Loss: 0.6690
# Precision: 0.3333, Recall: 0.0200, F1 Score: 0.0377
# Epoch 3/10
# Evaluation Loss: 0.6874
# Precision: 0.5000
# Recall: 0.0600
# F1 Score: 0.1071
# Training Loss: 0.6449, Validation Loss: 0.6874
# Precision: 0.5000, Recall: 0.0600, F1 Score: 0.1071
# Epoch 4/10
# Evaluation Loss: 0.6677
# Precision: 0.3333
# Recall: 0.0200
# F1 Score: 0.0377
# Training Loss: 0.6275, Validation Loss: 0.6677
# Precision: 0.3333, Recall: 0.0200, F1 Score: 0.0377
# Epoch 5/10
# Evaluation Loss: 0.6690
# Precision: 0.5000
# Recall: 0.0400
# F1 Score: 0.0741
# Training Loss: 0.6199, Validation Loss: 0.6690
# Precision: 0.5000, Recall: 0.0400, F1 Score: 0.0741
# Epoch 6/10
# Evaluation Loss: 0.6539
# Precision: 0.3333
# Recall: 0.0200
# F1 Score: 0.0377
# Training Loss: 0.6307, Validation Loss: 0.6539
# Precision: 0.3333, Recall: 0.0200, F1 Score: 0.0377
# Epoch 7/10
# Evaluation Loss: 0.6579
# Precision: 0.3333
# Recall: 0.0200
# F1 Score: 0.0377
# Training Loss: 0.6036, Validation Loss: 0.6579
# Precision: 0.3333, Recall: 0.0200, F1 Score: 0.0377
# Epoch 8/10
# Evaluation Loss: 0.6495
# Precision: 0.3333
# Recall: 0.0200
# F1 Score: 0.0377
# Training Loss: 0.6039, Validation Loss: 0.6495
# Precision: 0.3333, Recall: 0.0200, F1 Score: 0.0377
# Epoch 9/10
# Evaluation Loss: 0.6822
# Precision: 0.6667
# Recall: 0.0800
# F1 Score: 0.1429
# Training Loss: 0.6070, Validation Loss: 0.6822
# Precision: 0.6667, Recall: 0.0800, F1 Score: 0.1429
# Epoch 10/10
# Evaluation Loss: 0.6661
# Precision: 0.5000
# Recall: 0.0400
# F1 Score: 0.0741
# Training Loss: 0.6027, Validation Loss: 0.6661
# Precision: 0.5000, Recall: 0.0400, F1 Score: 0.0741
# Results for Fold 0: Validation Loss = 0.6661, Precision = 0.5000, Recall = 0.0400, F1 Score = 0.0741
# --------------------------------------------------
# ------ Fold 2/10 ------
# Epoch 1/10
# Evaluation Loss: 0.6491
# Precision: 0.5000
# Recall: 0.0377
# F1 Score: 0.0702
# Training Loss: 0.6605, Validation Loss: 0.6491
# Precision: 0.5000, Recall: 0.0377, F1 Score: 0.0702
# Epoch 2/10
# Evaluation Loss: 0.6628
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6415, Validation Loss: 0.6628
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 3/10
# Evaluation Loss: 0.6752
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6297, Validation Loss: 0.6752
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 4/10
# Evaluation Loss: 0.6737
# Precision: 0.6667
# Recall: 0.0377
# F1 Score: 0.0714
# Training Loss: 0.6255, Validation Loss: 0.6737
# Precision: 0.6667, Recall: 0.0377, F1 Score: 0.0714
# Epoch 5/10
# Evaluation Loss: 0.6390
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6395, Validation Loss: 0.6390
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 6/10
# Evaluation Loss: 0.7004
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6089, Validation Loss: 0.7004
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 7/10
# Evaluation Loss: 0.6520
# Precision: 0.5000
# Recall: 0.0189
# F1 Score: 0.0364
# Training Loss: 0.6108, Validation Loss: 0.6520
# Precision: 0.5000, Recall: 0.0189, F1 Score: 0.0364
# Epoch 8/10
# Evaluation Loss: 0.6758
# Precision: 0.7500
# Recall: 0.0566
# F1 Score: 0.1053
# Training Loss: 0.6100, Validation Loss: 0.6758
# Precision: 0.7500, Recall: 0.0566, F1 Score: 0.1053
# Epoch 9/10
# Evaluation Loss: 0.6596
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.5883, Validation Loss: 0.6596
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 10/10
# Evaluation Loss: 0.7115
# Precision: 0.6667
# Recall: 0.0377
# F1 Score: 0.0714
# Training Loss: 0.5852, Validation Loss: 0.7115
# Precision: 0.6667, Recall: 0.0377, F1 Score: 0.0714
# Results for Fold 1: Validation Loss = 0.7115, Precision = 0.6667, Recall = 0.0377, F1 Score = 0.0714
# --------------------------------------------------
# ------ Fold 3/10 ------
# Epoch 1/10
# Evaluation Loss: 0.6272
# Precision: 0.5000
# Recall: 0.0244
# F1 Score: 0.0465
# Training Loss: 0.6522, Validation Loss: 0.6272
# Precision: 0.5000, Recall: 0.0244, F1 Score: 0.0465
# Epoch 2/10
# Evaluation Loss: 0.6324
# Precision: 0.3333
# Recall: 0.0244
# F1 Score: 0.0455
# Training Loss: 0.6371, Validation Loss: 0.6324
# Precision: 0.3333, Recall: 0.0244, F1 Score: 0.0455
# Epoch 3/10
# Evaluation Loss: 0.6191
# Precision: 0.3333
# Recall: 0.0244
# F1 Score: 0.0455
# Training Loss: 0.6287, Validation Loss: 0.6191
# Precision: 0.3333, Recall: 0.0244, F1 Score: 0.0455
# Epoch 4/10
# Evaluation Loss: 0.6551
# Precision: 0.3333
# Recall: 0.0244
# F1 Score: 0.0455
# Training Loss: 0.6413, Validation Loss: 0.6551
# Precision: 0.3333, Recall: 0.0244, F1 Score: 0.0455
# Epoch 5/10
# Evaluation Loss: 0.6427
# Precision: 0.3333
# Recall: 0.0244
# F1 Score: 0.0455
# Training Loss: 0.6153, Validation Loss: 0.6427
# Precision: 0.3333, Recall: 0.0244, F1 Score: 0.0455
# Epoch 6/10
# Evaluation Loss: 0.6267
# Precision: 0.3333
# Recall: 0.0244
# F1 Score: 0.0455
# Training Loss: 0.6078, Validation Loss: 0.6267
# Precision: 0.3333, Recall: 0.0244, F1 Score: 0.0455
# Epoch 7/10
# Evaluation Loss: 0.6406
# Precision: 0.3333
# Recall: 0.0244
# F1 Score: 0.0455
# Training Loss: 0.6119, Validation Loss: 0.6406
# Precision: 0.3333, Recall: 0.0244, F1 Score: 0.0455
# Epoch 8/10
# Evaluation Loss: 0.6162
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.5973, Validation Loss: 0.6162
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 9/10
# Evaluation Loss: 0.6353
# Precision: 0.3333
# Recall: 0.0244
# F1 Score: 0.0455
# Training Loss: 0.5898, Validation Loss: 0.6353
# Precision: 0.3333, Recall: 0.0244, F1 Score: 0.0455
# Epoch 10/10
# Evaluation Loss: 0.6000
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.5789, Validation Loss: 0.6000
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Results for Fold 2: Validation Loss = 0.6000, Precision = 0.0000, Recall = 0.0000, F1 Score = 0.0000
# --------------------------------------------------
# ------ Fold 4/10 ------
# Epoch 1/10
# Evaluation Loss: 0.6979
# Precision: 1.0000
# Recall: 0.0200
# F1 Score: 0.0392
# Training Loss: 0.6766, Validation Loss: 0.6979
# Precision: 1.0000, Recall: 0.0200, F1 Score: 0.0392
# Epoch 2/10
# Evaluation Loss: 0.6604
# Precision: 1.0000
# Recall: 0.0600
# F1 Score: 0.1132
# Training Loss: 0.6663, Validation Loss: 0.6604
# Precision: 1.0000, Recall: 0.0600, F1 Score: 0.1132
# Epoch 3/10
# Evaluation Loss: 0.6849
# Precision: 0.5714
# Recall: 0.0800
# F1 Score: 0.1404
# Training Loss: 0.6508, Validation Loss: 0.6849
# Precision: 0.5714, Recall: 0.0800, F1 Score: 0.1404
# Epoch 4/10
# Evaluation Loss: 0.6718
# Precision: 1.0000
# Recall: 0.0600
# F1 Score: 0.1132
# Training Loss: 0.6519, Validation Loss: 0.6718
# Precision: 1.0000, Recall: 0.0600, F1 Score: 0.1132
# Epoch 5/10
# Evaluation Loss: 0.6404
# Precision: 1.0000
# Recall: 0.0600
# F1 Score: 0.1132
# Training Loss: 0.6270, Validation Loss: 0.6404
# Precision: 1.0000, Recall: 0.0600, F1 Score: 0.1132
# Epoch 6/10
# Evaluation Loss: 0.6944
# Precision: 1.0000
# Recall: 0.0400
# F1 Score: 0.0769
# Training Loss: 0.6300, Validation Loss: 0.6944
# Precision: 1.0000, Recall: 0.0400, F1 Score: 0.0769
# Epoch 7/10
# Evaluation Loss: 0.6474
# Precision: 0.7500
# Recall: 0.0600
# F1 Score: 0.1111
# Training Loss: 0.6212, Validation Loss: 0.6474
# Precision: 0.7500, Recall: 0.0600, F1 Score: 0.1111
# Epoch 8/10
# Evaluation Loss: 0.6291
# Precision: 1.0000
# Recall: 0.0400
# F1 Score: 0.0769
# Training Loss: 0.6026, Validation Loss: 0.6291
# Precision: 1.0000, Recall: 0.0400, F1 Score: 0.0769
# Epoch 9/10
# Evaluation Loss: 0.6423
# Precision: 0.7500
# Recall: 0.0600
# F1 Score: 0.1111
# Training Loss: 0.6057, Validation Loss: 0.6423
# Precision: 0.7500, Recall: 0.0600, F1 Score: 0.1111
# Epoch 10/10
# Evaluation Loss: 0.6489
# Precision: 0.7500
# Recall: 0.0600
# F1 Score: 0.1111
# Training Loss: 0.5964, Validation Loss: 0.6489
# Precision: 0.7500, Recall: 0.0600, F1 Score: 0.1111
# Results for Fold 3: Validation Loss = 0.6489, Precision = 0.7500, Recall = 0.0600, F1 Score = 0.1111
# --------------------------------------------------
# ------ Fold 5/10 ------
# Epoch 1/10
# Evaluation Loss: 0.5526
# Precision: 0.5000
# Recall: 0.0286
# F1 Score: 0.0541
# Training Loss: 0.6697, Validation Loss: 0.5526
# Precision: 0.5000, Recall: 0.0286, F1 Score: 0.0541
# Epoch 2/10
# Evaluation Loss: 0.5937
# Precision: 0.4286
# Recall: 0.0857
# F1 Score: 0.1429
# Training Loss: 0.6510, Validation Loss: 0.5937
# Precision: 0.4286, Recall: 0.0857, F1 Score: 0.1429
# Epoch 3/10
# Evaluation Loss: 0.6233
# Precision: 0.5000
# Recall: 0.0286
# F1 Score: 0.0541
# Training Loss: 0.6441, Validation Loss: 0.6233
# Precision: 0.5000, Recall: 0.0286, F1 Score: 0.0541
# Epoch 4/10
# Evaluation Loss: 0.5911
# Precision: 0.5000
# Recall: 0.0571
# F1 Score: 0.1026
# Training Loss: 0.6499, Validation Loss: 0.5911
# Precision: 0.5000, Recall: 0.0571, F1 Score: 0.1026
# Epoch 5/10
# Evaluation Loss: 0.5964
# Precision: 0.6667
# Recall: 0.0571
# F1 Score: 0.1053
# Training Loss: 0.6326, Validation Loss: 0.5964
# Precision: 0.6667, Recall: 0.0571, F1 Score: 0.1053
# Epoch 6/10
# Evaluation Loss: 0.6053
# Precision: 0.5000
# Recall: 0.0571
# F1 Score: 0.1026
# Training Loss: 0.6257, Validation Loss: 0.6053
# Precision: 0.5000, Recall: 0.0571, F1 Score: 0.1026
# Epoch 7/10
# Evaluation Loss: 0.5897
# Precision: 0.5000
# Recall: 0.0857
# F1 Score: 0.1463
# Training Loss: 0.6222, Validation Loss: 0.5897
# Precision: 0.5000, Recall: 0.0857, F1 Score: 0.1463
# Epoch 8/10
# Evaluation Loss: 0.5661
# Precision: 0.5000
# Recall: 0.0571
# F1 Score: 0.1026
# Training Loss: 0.6210, Validation Loss: 0.5661
# Precision: 0.5000, Recall: 0.0571, F1 Score: 0.1026
# Epoch 9/10
# Evaluation Loss: 0.6159
# Precision: 0.4545
# Recall: 0.1429
# F1 Score: 0.2174
# Training Loss: 0.6139, Validation Loss: 0.6159
# Precision: 0.4545, Recall: 0.1429, F1 Score: 0.2174
# Epoch 10/10
# Evaluation Loss: 0.6170
# Precision: 0.5000
# Recall: 0.0571
# F1 Score: 0.1026
# Training Loss: 0.5960, Validation Loss: 0.6170
# Precision: 0.5000, Recall: 0.0571, F1 Score: 0.1026
# Results for Fold 4: Validation Loss = 0.6170, Precision = 0.5000, Recall = 0.0571, F1 Score = 0.1026
# --------------------------------------------------
# ------ Fold 6/10 ------
# Epoch 1/10
# Evaluation Loss: 0.7117
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6838, Validation Loss: 0.7117
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 2/10
# Evaluation Loss: 0.7063
# Precision: 0.1667
# Recall: 0.0192
# F1 Score: 0.0345
# Training Loss: 0.6705, Validation Loss: 0.7063
# Precision: 0.1667, Recall: 0.0192, F1 Score: 0.0345
# Epoch 3/10
# Evaluation Loss: 0.7228
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6410, Validation Loss: 0.7228
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 4/10
# Evaluation Loss: 0.6952
# Precision: 0.2000
# Recall: 0.0192
# F1 Score: 0.0351
# Training Loss: 0.6334, Validation Loss: 0.6952
# Precision: 0.2000, Recall: 0.0192, F1 Score: 0.0351
# Epoch 5/10
# Evaluation Loss: 0.6814
# Precision: 0.2000
# Recall: 0.0192
# F1 Score: 0.0351
# Training Loss: 0.6292, Validation Loss: 0.6814
# Precision: 0.2000, Recall: 0.0192, F1 Score: 0.0351
# Epoch 6/10
# Evaluation Loss: 0.7217
# Precision: 0.2000
# Recall: 0.0192
# F1 Score: 0.0351
# Training Loss: 0.6255, Validation Loss: 0.7217
# Precision: 0.2000, Recall: 0.0192, F1 Score: 0.0351
# Epoch 7/10
# Evaluation Loss: 0.7349
# Precision: 0.2500
# Recall: 0.0192
# F1 Score: 0.0357
# Training Loss: 0.6101, Validation Loss: 0.7349
# Precision: 0.2500, Recall: 0.0192, F1 Score: 0.0357
# Epoch 8/10
# Evaluation Loss: 0.7067
# Precision: 0.2500
# Recall: 0.0192
# F1 Score: 0.0357
# Training Loss: 0.6223, Validation Loss: 0.7067
# Precision: 0.2500, Recall: 0.0192, F1 Score: 0.0357
# Epoch 9/10
# Evaluation Loss: 0.7548
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6131, Validation Loss: 0.7548
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 10/10
# Evaluation Loss: 0.7218
# Precision: 0.2857
# Recall: 0.0385
# F1 Score: 0.0678
# Training Loss: 0.5934, Validation Loss: 0.7218
# Precision: 0.2857, Recall: 0.0385, F1 Score: 0.0678
# Results for Fold 5: Validation Loss = 0.7218, Precision = 0.2857, Recall = 0.0385, F1 Score = 0.0678
# --------------------------------------------------
# ------ Fold 7/10 ------
# Epoch 1/10
# Evaluation Loss: 0.6255
# Precision: 0.3333
# Recall: 0.0204
# F1 Score: 0.0385
# Training Loss: 0.6655, Validation Loss: 0.6255
# Precision: 0.3333, Recall: 0.0204, F1 Score: 0.0385
# Epoch 2/10
# Evaluation Loss: 0.6383
# Precision: 0.2500
# Recall: 0.0204
# F1 Score: 0.0377
# Training Loss: 0.6435, Validation Loss: 0.6383
# Precision: 0.2500, Recall: 0.0204, F1 Score: 0.0377
# Epoch 3/10
# Evaluation Loss: 0.6588
# Precision: 0.2000
# Recall: 0.0204
# F1 Score: 0.0370
# Training Loss: 0.6447, Validation Loss: 0.6588
# Precision: 0.2000, Recall: 0.0204, F1 Score: 0.0370
# Epoch 4/10
# Evaluation Loss: 0.6992
# Precision: 0.3333
# Recall: 0.0408
# F1 Score: 0.0727
# Training Loss: 0.6329, Validation Loss: 0.6992
# Precision: 0.3333, Recall: 0.0408, F1 Score: 0.0727
# Epoch 5/10
# Evaluation Loss: 0.6959
# Precision: 0.2000
# Recall: 0.0204
# F1 Score: 0.0370
# Training Loss: 0.6254, Validation Loss: 0.6959
# Precision: 0.2000, Recall: 0.0204, F1 Score: 0.0370
# Epoch 6/10
# Evaluation Loss: 0.6735
# Precision: 0.2000
# Recall: 0.0204
# F1 Score: 0.0370
# Training Loss: 0.6080, Validation Loss: 0.6735
# Precision: 0.2000, Recall: 0.0204, F1 Score: 0.0370
# Epoch 7/10
# Evaluation Loss: 0.6828
# Precision: 0.3333
# Recall: 0.0408
# F1 Score: 0.0727
# Training Loss: 0.6087, Validation Loss: 0.6828
# Precision: 0.3333, Recall: 0.0408, F1 Score: 0.0727
# Epoch 8/10
# Evaluation Loss: 0.6433
# Precision: 0.2000
# Recall: 0.0204
# F1 Score: 0.0370
# Training Loss: 0.5979, Validation Loss: 0.6433
# Precision: 0.2000, Recall: 0.0204, F1 Score: 0.0370
# Epoch 9/10
# Evaluation Loss: 0.6908
# Precision: 0.2500
# Recall: 0.0408
# F1 Score: 0.0702
# Training Loss: 0.5882, Validation Loss: 0.6908
# Precision: 0.2500, Recall: 0.0408, F1 Score: 0.0702
# Epoch 10/10
# Evaluation Loss: 0.6670
# Precision: 0.2500
# Recall: 0.0408
# F1 Score: 0.0702
# Training Loss: 0.5839, Validation Loss: 0.6670
# Precision: 0.2500, Recall: 0.0408, F1 Score: 0.0702
# Results for Fold 6: Validation Loss = 0.6670, Precision = 0.2500, Recall = 0.0408, F1 Score = 0.0702
# --------------------------------------------------
# ------ Fold 8/10 ------
# Epoch 1/10
# Evaluation Loss: 0.6507
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6599, Validation Loss: 0.6507
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 2/10
# Evaluation Loss: 0.6735
# Precision: 0.3333
# Recall: 0.0417
# F1 Score: 0.0741
# Training Loss: 0.6467, Validation Loss: 0.6735
# Precision: 0.3333, Recall: 0.0417, F1 Score: 0.0741
# Epoch 3/10
# Evaluation Loss: 0.6547
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6382, Validation Loss: 0.6547
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 4/10
# Evaluation Loss: 0.6529
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6297, Validation Loss: 0.6529
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 5/10
# Evaluation Loss: 0.6716
# Precision: 0.2500
# Recall: 0.0417
# F1 Score: 0.0714
# Training Loss: 0.6226, Validation Loss: 0.6716
# Precision: 0.2500, Recall: 0.0417, F1 Score: 0.0714
# Epoch 6/10
# Evaluation Loss: 0.6402
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6200, Validation Loss: 0.6402
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 7/10
# Evaluation Loss: 0.6749
# Precision: 0.1667
# Recall: 0.0208
# F1 Score: 0.0370
# Training Loss: 0.6069, Validation Loss: 0.6749
# Precision: 0.1667, Recall: 0.0208, F1 Score: 0.0370
# Epoch 8/10
# Evaluation Loss: 0.6248
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6018, Validation Loss: 0.6248
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 9/10
# Evaluation Loss: 0.6773
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.5922, Validation Loss: 0.6773
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 10/10
# Evaluation Loss: 0.6578
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.5936, Validation Loss: 0.6578
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Results for Fold 7: Validation Loss = 0.6578, Precision = 0.0000, Recall = 0.0000, F1 Score = 0.0000
# --------------------------------------------------
# ------ Fold 9/10 ------
# Epoch 1/10
# Evaluation Loss: 0.6686
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6514, Validation Loss: 0.6686
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 2/10
# Evaluation Loss: 0.6440
# Precision: 0.3333
# Recall: 0.0222
# F1 Score: 0.0417
# Training Loss: 0.6472, Validation Loss: 0.6440
# Precision: 0.3333, Recall: 0.0222, F1 Score: 0.0417
# Epoch 3/10
# Evaluation Loss: 0.6814
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6308, Validation Loss: 0.6814
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 4/10
# Evaluation Loss: 0.6349
# Precision: 0.2000
# Recall: 0.0222
# F1 Score: 0.0400
# Training Loss: 0.6244, Validation Loss: 0.6349
# Precision: 0.2000, Recall: 0.0222, F1 Score: 0.0400
# Epoch 5/10
# Evaluation Loss: 0.6784
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6212, Validation Loss: 0.6784
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 6/10
# Evaluation Loss: 0.6644
# Precision: 0.3333
# Recall: 0.0222
# F1 Score: 0.0417
# Training Loss: 0.6098, Validation Loss: 0.6644
# Precision: 0.3333, Recall: 0.0222, F1 Score: 0.0417
# Epoch 7/10
# Evaluation Loss: 0.6718
# Precision: 0.1667
# Recall: 0.0222
# F1 Score: 0.0392
# Training Loss: 0.6146, Validation Loss: 0.6718
# Precision: 0.1667, Recall: 0.0222, F1 Score: 0.0392
# Epoch 8/10
# Evaluation Loss: 0.6862
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.5962, Validation Loss: 0.6862
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 9/10
# Evaluation Loss: 0.6825
# Precision: 0.2500
# Recall: 0.0444
# F1 Score: 0.0755
# Training Loss: 0.5929, Validation Loss: 0.6825
# Precision: 0.2500, Recall: 0.0444, F1 Score: 0.0755
# Epoch 10/10
# Evaluation Loss: 0.6663
# Precision: 0.1667
# Recall: 0.0222
# F1 Score: 0.0392
# Training Loss: 0.5847, Validation Loss: 0.6663
# Precision: 0.1667, Recall: 0.0222, F1 Score: 0.0392
# Results for Fold 8: Validation Loss = 0.6663, Precision = 0.1667, Recall = 0.0222, F1 Score = 0.0392
# --------------------------------------------------
# ------ Fold 10/10 ------
# Epoch 1/10
# Evaluation Loss: 0.6211
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6734, Validation Loss: 0.6211
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 2/10
# Evaluation Loss: 0.6077
# Precision: 0.3333
# Recall: 0.0238
# F1 Score: 0.0444
# Training Loss: 0.6558, Validation Loss: 0.6077
# Precision: 0.3333, Recall: 0.0238, F1 Score: 0.0444
# Epoch 3/10
# Evaluation Loss: 0.5920
# Precision: 0.3333
# Recall: 0.0238
# F1 Score: 0.0444
# Training Loss: 0.6498, Validation Loss: 0.5920
# Precision: 0.3333, Recall: 0.0238, F1 Score: 0.0444
# Epoch 4/10
# Evaluation Loss: 0.6006
# Precision: 0.3333
# Recall: 0.0238
# F1 Score: 0.0444
# Training Loss: 0.6365, Validation Loss: 0.6006
# Precision: 0.3333, Recall: 0.0238, F1 Score: 0.0444
# Epoch 5/10
# Evaluation Loss: 0.6164
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6333, Validation Loss: 0.6164
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 6/10
# Evaluation Loss: 0.6323
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6186, Validation Loss: 0.6323
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 7/10
# Evaluation Loss: 0.6201
# Precision: 0.5714
# Recall: 0.0952
# F1 Score: 0.1633
# Training Loss: 0.6305, Validation Loss: 0.6201
# Precision: 0.5714, Recall: 0.0952, F1 Score: 0.1633
# Epoch 8/10
# Evaluation Loss: 0.6133
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6206, Validation Loss: 0.6133
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 9/10
# Evaluation Loss: 0.5883
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.5976, Validation Loss: 0.5883
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 10/10
# Evaluation Loss: 0.6078
# Precision: 0.6000
# Recall: 0.0714
# F1 Score: 0.1277
# Training Loss: 0.6003, Validation Loss: 0.6078
# Precision: 0.6000, Recall: 0.0714, F1 Score: 0.1277
# Results for Fold 9: Validation Loss = 0.6078, Precision = 0.6000, Recall = 0.0714, F1 Score = 0.1277
# --------------------------------------------------
#
# K-Fold Cross-Validation Results:
# Average Loss: 0.6564
# Average Precision: 0.3719
# Average Recall: 0.0368
# Average F1 Score: 0.0664
# F1 scores per fold saved to results/simulParallel-Xie-F1_scores.npy
