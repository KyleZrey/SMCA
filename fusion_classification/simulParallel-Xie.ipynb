# %%
import sys
import os
import numpy as np
import pandas as pd
import torch
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset, Dataset, Subset
from torcheval.metrics import BinaryPrecision, BinaryRecall, BinaryF1Score
from sklearn.model_selection import train_test_split, KFold

# %%
# Append the path for module imports
sys.path.append('../')

# Import custom modules
from modules.cross_attentionb import CrossAttentionB
from modules.dataloader import load_npy_files
from modules.classifier import DenseLayer, BCELoss, BCEWithLogits

# %% [markdown]
# ### Data Loading

# %%
# Load the labels DataFrame
id_label_df = pd.read_excel('../misc/MM-Trailer_dataset.xlsx')

# Define the directories
text_features_dir = 'C:\\Users\\edjin\\OneDrive\\Documents\\Programming Files\\Thesis\\SMCA\\misc\\textStream_BERT\\feature_vectors\\feature_vectors'
audio_features_dir = 'C:\\Users\\edjin\\OneDrive\\Documents\\Programming Files\\Thesis\\SMCA\\misc\\audio_fe\\logmel_spectrograms'
video_features_dir = 'C:\\Users\\edjin\\OneDrive\\Documents\\Programming Files\\Thesis\\SMCA\\misc\\visualStream_ViT\\feature_vectors'

# Load the feature vectors from each directory
text_features = load_npy_files(text_features_dir)
audio_features = load_npy_files(audio_features_dir)
video_features = load_npy_files(video_features_dir)

print(f"Number of text feature vectors loaded: {len(text_features)}")
print(f"Number of audio feature vectors loaded: {len(audio_features)}")
print(f"Number of video feature vectors loaded: {len(video_features)}")
# Out:
# Number of text feature vectors loaded: 1353
# Number of audio feature vectors loaded: 1353
# Number of video feature vectors loaded: 1353

# %%
# Cross Attention Function
def PairCrossAttention(modalityAlpha, modalityBeta, d_out_kq=768, d_out_v=768):
    cross_attn = CrossAttentionB(modalityAlpha.shape[-1], modalityBeta.shape[-1], d_out_kq, d_out_v)
    modalityAlphaBeta = cross_attn(modalityAlpha, modalityBeta)
    return modalityAlphaBeta

# %%
def HadamardProduct(tensor1, tensor2):
    # Ensure both tensors have the same shape
    if tensor1.shape != tensor2.shape:
        raise ValueError("Tensors must have the same shape for Hadamard product.")
    
    # Compute the Hadamard product
    return tensor1 * tensor2

# %%
class EmbracementLayer(nn.Module):
    def __init__(self, d_in, d_out):
        super(EmbracementLayer, self).__init__()
        self.fc = nn.Linear(d_in, d_out)
        self.norm = nn.LayerNorm(d_out)
        self.activation = nn.ReLU()

    def forward(self, video_features, audio_features, text_features):
        # Concatenate features along the last dimension
        combined_features = torch.cat([video_features, audio_features, text_features], dim=-1)
        
        # Apply linear transformation
        transformed_features = self.fc(combined_features)
        
        # Apply normalization and activation
        norm_features = self.norm(transformed_features)
        output = self.activation(norm_features)
        
        return output

# %% [markdown]
# ### Model Training

# %%
def get_optimizer(parameters, lr=1e-3):
    # Create an optimizer, for example, Adam
    return optim.Adam(parameters, lr=lr)

# %%
def train_model(dense_layer, dataloader, criterion, optimizer, device):
    dense_layer.train()  # Set the model to training mode
    total_loss = 0.0

    for batch in dataloader:
        # Assuming batch is a tuple (fused_features, targets)
        fused_features, targets = batch

        # Move tensors to the specified device
        fused_features = fused_features.to(device)
        targets = targets.to(device)

        # Clear gradients
        optimizer.zero_grad()

        # Pass the fused features through the dense layer
        predictions = dense_layer(fused_features).view(-1)    # Ensure correct shape

        # Compute loss
        loss = criterion(predictions, targets)

        # Backward pass and optimization
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    return total_loss / len(dataloader)

# %%
def evaluate_model(dense_layer, dataloader, criterion, device):
    dense_layer.eval()
    total_loss = 0

    # Initialize the metrics for binary classification
    precision_metric = BinaryPrecision().to(device)
    recall_metric = BinaryRecall().to(device)
    f1_metric = BinaryF1Score().to(device)
    
    with torch.no_grad():
        for fused_features, targets in dataloader:
            fused_features, targets = (
                fused_features.to(device),  # Use fused features directly
                targets.to(device).squeeze()
            )

            # Pass the fused features through the dense layer
            predictions = dense_layer(fused_features).view(-1)
            
            # Compute loss
            loss = criterion(predictions, targets)
            total_loss += loss.item()

            # Apply threshold to get binary predictions
            preds = (predictions > 0.5).float()
            
            # Update the precision, recall, and F1 score metrics
            precision_metric.update(preds.long(), targets.long())
            recall_metric.update(preds.long(), targets.long())
            f1_metric.update(preds.long(), targets.long())

    # Compute precision, recall, and F1 score
    precision = precision_metric.compute().item()
    recall = recall_metric.compute().item()
    f1_score = f1_metric.compute().item()

    average_loss = total_loss / len(dataloader)

    print(f"Evaluation Loss: {average_loss:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1_score:.4f}")
    
    return average_loss, precision, recall, f1_score

# %%
def test_model(dense_layer, dataloader, criterion, device):
    dense_layer.eval()  # Set the model to evaluation mode
    total_loss = 0

    # Initialize the metrics for binary classification
    precision_metric = BinaryPrecision().to(device)
    recall_metric = BinaryRecall().to(device)
    f1_metric = BinaryF1Score().to(device)

    with torch.no_grad():
        for fused_features, targets in dataloader:
            fused_features, targets = (
                fused_features.to(device),  # Move fused features to device
                targets.to(device).squeeze()  # Ensure targets are the correct shape
            )

            # Pass the fused features through the dense layer
            predictions = dense_layer(fused_features).view(-1)  
            
            # Compute loss
            loss = criterion(predictions, targets)
            total_loss += loss.item()

            # Apply threshold to get binary predictions
            preds = (predictions > 0.5).float()
            
            # Update the precision, recall, and F1 score metrics
            precision_metric.update(preds.long(), targets.long())
            recall_metric.update(preds.long(), targets.long())
            f1_metric.update(preds.long(), targets.long())

    # Compute precision, recall, and F1 score
    precision = precision_metric.compute().item()
    recall = recall_metric.compute().item()
    f1_score = f1_metric.compute().item()

    average_loss = total_loss / len(dataloader)

    print(f"Test Loss: {average_loss:.4f}")
    print(f"Test Precision: {precision:.4f}")
    print(f"Test Recall: {recall:.4f}")
    print(f"Test F1 Score: {f1_score:.4f}")

    return average_loss, precision, recall, f1_score

# %% [markdown]
# ### Fusion

# %%
# Initialize list to store fused features for each file
fused_features_list = []
labels_list = []
batch_size = 32  # Adjust based on your available memory

for batch_start in range(0, len(text_features), batch_size):
    batch_end = min(batch_start + batch_size, len(text_features))
    batch_text_features = text_features[batch_start:batch_end]
    batch_audio_features = audio_features[batch_start:batch_end]
    batch_video_features = video_features[batch_start:batch_end]
    print(f"Batch: {batch_start}")
    # Loop through all the files in the dataset
    for i in range(len(batch_text_features)):
        # Extract features for the current file
        text_file_name, text_feature = text_features[i]  # Renamed to avoid shadowing
        audio_file_name, audio_feature = audio_features[i]  # Renamed to avoid shadowing
        video_file_name, video_feature = video_features[i]  # Renamed to avoid shadowing

        # print(f"Processing file {text_file_name}")

        # Check if any features are missing
        if text_feature is None or audio_feature is None or video_feature is None:
            print(f"Skipping file {i + 1}/{len(text_features)}: Missing features for {text_file_name}, {audio_file_name}, {video_file_name}")
            continue  # Skip to the next iteration

        # print("Text file name:", text_file_name)
        # print("Audio file name:", audio_file_name)
        # print("Video file name:", video_file_name)

        print("Text features shape:", text_feature.shape)
        print("Audio features shape:", audio_feature.shape)
        print("Video features shape:", video_feature.shape)

        # Reshape features
        audio_feature = audio_feature.squeeze(0)  # Changed from audio_features to audio_feature
        text_feature = text_feature.unsqueeze(0)  # Changed from text_features to text_feature

        # print("text_features shape:", text_feature.shape)
        # print("audio_features shape:", audio_feature.shape)
        # print("video_features shape:", video_feature.shape, '\n')


        with torch.no_grad():
            # Cross-Attention for every possible pair
            text_video = PairCrossAttention(text_feature, video_feature)
            text_audio = PairCrossAttention(text_feature, audio_feature)
            audio_video = PairCrossAttention(audio_feature, video_feature)
            audio_text = PairCrossAttention(audio_feature, text_feature)
            video_audio = PairCrossAttention(video_feature, audio_feature)
            video_text = PairCrossAttention(video_feature, text_feature)

            # print("video_audio shape:", video_audio.shape)
            # print("video_text shape:", video_text.shape)
            # print("audio_video shape:", audio_video.shape)
            # print("audio_text shape:", audio_text.shape)
            # print("text_video shape:", text_video.shape)
            # print("text_audio shape:", text_audio.shape, '\n')

            # Combine Cross-Attention outputs using Hadamard product
            text_combined = HadamardProduct(text_video, text_audio)
            audio_combined = HadamardProduct(audio_video, audio_text)
            video_combined = HadamardProduct(video_audio, video_text)

            # Fusion using Embracement Layer
            d_in = video_combined.shape[-1] + audio_combined.shape[-1] + text_combined.shape[-1]
            embracement_layer = EmbracementLayer(d_in, d_in)
            
            # Fused features for the current file
            fused_features = embracement_layer(video_combined[-1], audio_combined[-1], text_combined[-1])
            
            print("Fused Features Shape:", fused_features.shape, '\n')

            # Append the fused features and the corresponding label to the lists
            fused_features_list.append(fused_features)
            label = id_label_df.iloc[i]['Label']  # Assuming you have a column 'Label'
            labels_list.append(label)

        del text_feature, audio_feature, video_feature
        del text_video, text_audio, audio_video, audio_text, video_audio, video_text
        
# Stack all fused features into a tensor for training
fused_features_tensor = torch.stack(fused_features_list)

# Convert labels to tensor
label_map = {'red': 1, 'green': 0}  # Adjust if your labels differ
labels_tensor = torch.tensor([label_map[label] for label in labels_list], dtype=torch.float32)
# Out:
# Batch: 0
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([95, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([124, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([136, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([116, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([113, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([126, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([131, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([134, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([140, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([147, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([139, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([144, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([98, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([162, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([104, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([151, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([12, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([105, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([67, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([108, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([88, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([191, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([82, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([101, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([102, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([244, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Batch: 32
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([95, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([124, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([136, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([116, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([113, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([126, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([131, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([134, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([140, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([147, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([139, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([144, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([98, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([162, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([104, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([151, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([12, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([105, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([67, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([108, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([88, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([191, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([82, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([101, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([102, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([244, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Batch: 64
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([95, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([124, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([136, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([116, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([113, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([126, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([131, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([134, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([140, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([147, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([139, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([144, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([98, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([162, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([104, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([151, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([12, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([105, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([67, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([108, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([88, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([191, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([82, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([101, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([102, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([244, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Batch: 96
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([95, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([124, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([136, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([116, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([113, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([126, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([131, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([134, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([140, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([147, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([139, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([144, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([98, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([162, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([104, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([151, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([12, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([105, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([67, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([108, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([88, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([191, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([82, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([101, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([102, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([244, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Batch: 128
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([95, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([124, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([136, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([116, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([113, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([126, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([131, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([134, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([140, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([147, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([139, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([144, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([98, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([162, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([104, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([151, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([12, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([105, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([67, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([108, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([88, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([191, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([82, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([101, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([102, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([244, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Batch: 160
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([95, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([124, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([136, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([116, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([113, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([126, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([131, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([134, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([140, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([147, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([139, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([144, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([98, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([162, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([104, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([151, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([12, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([105, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([67, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([108, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([88, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([191, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([82, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([101, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([102, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([244, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Batch: 192
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([95, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([124, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([136, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([116, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([113, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([126, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([131, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([134, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([140, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([147, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([139, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([144, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([98, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([162, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([104, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([151, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([12, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([105, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([67, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([108, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([88, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([191, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([82, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([101, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([102, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([244, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Batch: 224
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([95, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([124, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([136, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([116, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([113, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([126, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([131, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([134, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([140, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([147, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([139, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([144, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([98, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([162, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([104, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([151, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([12, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([105, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([67, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([108, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([88, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([191, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([82, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([101, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([102, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([244, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Batch: 256
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([95, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([124, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([136, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([116, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([113, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([126, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([131, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([134, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([140, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([147, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([139, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([144, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# ...
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([139, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([144, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([98, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([162, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([104, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([151, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([12, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([105, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([67, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([108, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([88, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([191, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([82, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([101, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([102, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([244, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Batch: 1280
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([95, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([124, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([136, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([116, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([113, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([126, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([131, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([134, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([140, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([147, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([139, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([144, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([98, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([162, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([104, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([151, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([12, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([105, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([67, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([108, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([88, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([191, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([82, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([101, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([102, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([244, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Batch: 1312
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([95, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([124, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([136, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([116, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([113, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([126, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([131, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([134, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([140, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([147, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([137, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([139, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([144, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([98, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([162, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([104, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([151, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([12, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([105, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([67, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([108, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([88, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([191, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([82, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([101, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([102, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([244, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([110, 768])
# Fused Features Shape: torch.Size([2304])
#
# Batch: 1344
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([95, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([124, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([127, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([136, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([116, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([113, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([126, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([131, 768])
# Fused Features Shape: torch.Size([2304])
#
# Text features shape: torch.Size([1024])
# Audio features shape: torch.Size([1, 197, 768])
# Video features shape: torch.Size([134, 768])
# Fused Features Shape: torch.Size([2304])

# %%
# Splitting data for training, validation, and testing
train_df, val_test_df, train_labels, val_test_labels = train_test_split(
    fused_features_tensor, labels_tensor, test_size=0.3, random_state=42)

# Further splitting remaining set into validation and test sets
val_df, test_df, val_labels, test_labels = train_test_split(
    val_test_df, val_test_labels, test_size=0.5, random_state=42)

# Create DataLoaders
train_loader = DataLoader(list(zip(train_df, train_labels)), batch_size=32, shuffle=True)
val_loader = DataLoader(list(zip(val_df, val_labels)), batch_size=32, shuffle=False)
test_loader = DataLoader(list(zip(test_df, test_labels)), batch_size=32, shuffle=False)

# %%
if __name__ == "__main__":
    torch.manual_seed(42)

    # Check for device availability
    if torch.backends.mps.is_available():
        device = torch.device("mps")
    else:
        device = torch.device("cpu")

    # Input dimension based on fused features tensor
    input_dim = fused_features_tensor.shape[1]  # Adjust if necessary
    dense_layer = DenseLayer(input_size=input_dim).to(device)  # Initialize and move the dense layer to the correct device

    # Define the loss function and optimizer
    criterion = BCELoss()  # Use appropriate loss function
    optimizer = get_optimizer(dense_layer.parameters())  # Pass only the dense layer parameters

    # Training loop
    num_epochs = 10  # Set the number of epochs you want to train for

    for epoch in range(num_epochs):
        print(f"Epoch {epoch + 1}/{num_epochs}")

        # Ensure you have a dataloader that yields inputs and targets
        train_loss = train_model(dense_layer=dense_layer, dataloader=train_loader, criterion=criterion, optimizer=optimizer, device=device)
        
        # Validate model
        val_loss, precision, recall, f1_score = evaluate_model(dense_layer=dense_layer, dataloader=val_loader, criterion=criterion, device=device)

        print(f"Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")
        print("-" * 30)
    
    # Testing the model
    print("Testing the model on the test set...")
    test_loss, test_precision, test_recall, test_f1_score = test_model(dense_layer=dense_layer, dataloader=test_loader, criterion=criterion, device=device)
# Out:
# Epoch 1/10
# Evaluation Loss: 0.6981
# Precision: 0.3544
# Recall: 0.3636
# F1 Score: 0.3590
# Training Loss: 0.6798, Validation Loss: 0.6981
# ------------------------------
# Epoch 2/10
# Evaluation Loss: 0.6740
# Precision: 0.3810
# Recall: 0.1039
# F1 Score: 0.1633
# Training Loss: 0.5861, Validation Loss: 0.6740
# ------------------------------
# Epoch 3/10
# Evaluation Loss: 0.6790
# Precision: 0.4286
# Recall: 0.1558
# F1 Score: 0.2286
# Training Loss: 0.5219, Validation Loss: 0.6790
# ------------------------------
# Epoch 4/10
# Evaluation Loss: 0.6884
# Precision: 0.3333
# Recall: 0.1948
# F1 Score: 0.2459
# Training Loss: 0.4729, Validation Loss: 0.6884
# ------------------------------
# Epoch 5/10
# Evaluation Loss: 0.7035
# Precision: 0.5000
# Recall: 0.0390
# F1 Score: 0.0723
# Training Loss: 0.4269, Validation Loss: 0.7035
# ------------------------------
# Epoch 6/10
# Evaluation Loss: 0.6998
# Precision: 0.3684
# Recall: 0.1818
# F1 Score: 0.2435
# Training Loss: 0.3941, Validation Loss: 0.6998
# ------------------------------
# Epoch 7/10
# Evaluation Loss: 0.7435
# Precision: 0.5000
# Recall: 0.0260
# F1 Score: 0.0494
# Training Loss: 0.3571, Validation Loss: 0.7435
# ------------------------------
# Epoch 8/10
# Evaluation Loss: 0.7187
# Precision: 0.3571
# Recall: 0.1948
# F1 Score: 0.2521
# Training Loss: 0.3343, Validation Loss: 0.7187
# ------------------------------
# Epoch 9/10
# Evaluation Loss: 0.7287
# Precision: 0.3947
# Recall: 0.1948
# F1 Score: 0.2609
# Training Loss: 0.3079, Validation Loss: 0.7287
# ------------------------------
# Epoch 10/10
# Evaluation Loss: 0.7563
# Precision: 0.3846
# Recall: 0.1299
# F1 Score: 0.1942
# Training Loss: 0.2916, Validation Loss: 0.7563
# ------------------------------
# Testing the model on the test set...
# Test Loss: 0.6628
# Test Precision: 0.3200
# Test Recall: 0.1194
# Test F1 Score: 0.1739

# %% [markdown]
# ### K-Fold Evaluation

# %%
def cross_validate_model(
    fused_features_tensor, 
    labels_tensor, 
    num_folds, 
    num_epochs, 
    batch_size, 
    learning_rate,
    output_file,
    device=None
):
    # Set device configuration
    if device is None:
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Device: {device}")
  
    # Ensure the output directory exists
    output_dir = os.path.dirname(output_file)
    if output_dir and not os.path.exists(output_dir):
        os.makedirs(output_dir)  # Creates the directory if it does not exist
    
    # Create a TensorDataset from the features and labels
    dataset = TensorDataset(fused_features_tensor, labels_tensor)

    # Initialize KFold
    kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)

    # lists to store metrics for each fold
    fold_losses = []
    fold_precisions = []
    fold_recalls = []
    fold_f1_scores = []
    f1_scores_per_fold = []  # List to store F1 scores for each fold

    for fold, (train_idx, val_idx) in enumerate(kf.split(dataset)):
        print("-" * 50)
        print(f"------ Fold {fold + 1 }/{num_folds} ------")
     
        # Create data loaders for the train and validation sets
        train_sampler = torch.utils.data.SubsetRandomSampler(train_idx)
        val_sampler = torch.utils.data.SubsetRandomSampler(val_idx)
        
        train_dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, sampler=train_sampler)
        val_dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, sampler=val_sampler)

        # Initialize dense_layer, criterion, and optimizer
        dense_layer = DenseLayer(input_size=input_dim).to(device)  # Initialize and move the dense layer to the correct device  # Initialize your model here
        criterion = BCELoss()  # Example loss for binary classification
        optimizer = get_optimizer(dense_layer.parameters(), lr=learning_rate)

        # Train the model for the specified number of epochs
        for epoch in range(num_epochs):
            print(f"Epoch {epoch + 1}/{num_epochs}")
        
            train_loss = train_model(dense_layer, train_dataloader, criterion, optimizer, device)
            val_loss, precision, recall, f1_score = evaluate_model(dense_layer, val_dataloader, criterion, device)
            
            print(f"Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")
            print(f"Precision: {precision:.4f}, Recall: {recall:.4f}, F1 Score: {f1_score:.4f}")
            
        # Store the validation metrics for this fold
        print(f"Results for Fold {fold}: Validation Loss = {val_loss:.4f}, Precision = {precision:.4f}, Recall = {recall:.4f}, F1 Score = {f1_score:.4f}")
        fold_losses.append(val_loss)
        fold_precisions.append(precision)
        fold_recalls.append(recall)
        fold_f1_scores.append(f1_score)
        f1_scores_per_fold.append(f1_score)  # Save F1 score for the current fold

    # Calculate the average metrics across all folds
    avg_loss = np.mean(fold_losses)
    avg_precision = np.mean(fold_precisions)
    avg_recall = np.mean(fold_recalls)
    avg_f1_score = np.mean(fold_f1_scores)

    print("-" * 50)
    print("\nK-Fold Cross-Validation Results:")
    print(f"Average Loss: {avg_loss:.4f}")
    print(f"Average Precision: {avg_precision:.4f}")
    print(f"Average Recall: {avg_recall:.4f}")
    print(f"Average F1 Score: {avg_f1_score:.4f}")
    
    # Save F1 scores per fold to a .npy file
    np.save(output_file, np.array(f1_scores_per_fold))
    print(f"F1 scores per fold saved to {output_file}")

    return avg_loss, avg_precision, avg_recall, avg_f1_score

# %%
# Run k-fold cross-validation   
results = cross_validate_model(
    fused_features_tensor, 
    labels_tensor, 
    num_folds=5,
    num_epochs=50,
    batch_size=32,
    learning_rate=1e-5,
    output_file="results/simulParallel-Xie-F1_scores.npy"
)


# Input dimension based on fused features tensor
input_dim = fused_features_tensor.shape[1]  # Adjust if necessary
dense_layer = DenseLayer(input_size=input_dim).to(device)  # Initialize and move the dense layer to the correct device
criterion = BCELoss()  # Use appropriate loss function

# Set device configuration
if device is None:
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
    
# Testing the model
print("Testing the model on the test set...")
test_loss, test_precision, test_recall, test_f1_score = test_model(dense_layer=dense_layer, dataloader=test_loader, criterion=criterion, device=device)
# Out:
# Device: cuda
# --------------------------------------------------
# ------ Fold 1/5 ------
# Epoch 1/50
# Evaluation Loss: 0.7036
# Precision: 0.3846
# Recall: 0.4369
# F1 Score: 0.4091
# Training Loss: 0.7194, Validation Loss: 0.7036
# Precision: 0.3846, Recall: 0.4369, F1 Score: 0.4091
# Epoch 2/50
# Evaluation Loss: 0.6808
# Precision: 0.3939
# Recall: 0.2524
# F1 Score: 0.3077
# Training Loss: 0.6832, Validation Loss: 0.6808
# Precision: 0.3939, Recall: 0.2524, F1 Score: 0.3077
# Epoch 3/50
# Evaluation Loss: 0.6749
# Precision: 0.4103
# Recall: 0.1553
# F1 Score: 0.2254
# Training Loss: 0.6631, Validation Loss: 0.6749
# Precision: 0.4103, Recall: 0.1553, F1 Score: 0.2254
# Epoch 4/50
# Evaluation Loss: 0.6754
# Precision: 0.3889
# Recall: 0.0680
# F1 Score: 0.1157
# Training Loss: 0.6530, Validation Loss: 0.6754
# Precision: 0.3889, Recall: 0.0680, F1 Score: 0.1157
# Epoch 5/50
# Evaluation Loss: 0.6803
# Precision: 0.2000
# Recall: 0.0194
# F1 Score: 0.0354
# Training Loss: 0.6475, Validation Loss: 0.6803
# Precision: 0.2000, Recall: 0.0194, F1 Score: 0.0354
# Epoch 6/50
# Evaluation Loss: 0.6754
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6451, Validation Loss: 0.6754
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 7/50
# Evaluation Loss: 0.6812
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6433, Validation Loss: 0.6812
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 8/50
# Evaluation Loss: 0.6833
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6432, Validation Loss: 0.6833
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 9/50
# Evaluation Loss: 0.6792
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6418, Validation Loss: 0.6792
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 10/50
# Evaluation Loss: 0.6810
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6406, Validation Loss: 0.6810
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 11/50
# Evaluation Loss: 0.6788
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6403, Validation Loss: 0.6788
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 12/50
# Evaluation Loss: 0.6724
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6387, Validation Loss: 0.6724
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 13/50
# Evaluation Loss: 0.6827
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6387, Validation Loss: 0.6827
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 14/50
# Evaluation Loss: 0.6812
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6383, Validation Loss: 0.6812
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 15/50
# Evaluation Loss: 0.6849
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6361, Validation Loss: 0.6849
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 16/50
# Evaluation Loss: 0.6801
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6364, Validation Loss: 0.6801
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 17/50
# Evaluation Loss: 0.6855
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6353, Validation Loss: 0.6855
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 18/50
# Evaluation Loss: 0.6880
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6346, Validation Loss: 0.6880
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 19/50
# Evaluation Loss: 0.6777
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6333, Validation Loss: 0.6777
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 20/50
# Evaluation Loss: 0.6777
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6333, Validation Loss: 0.6777
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 21/50
# Evaluation Loss: 0.6724
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6333, Validation Loss: 0.6724
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 22/50
# Evaluation Loss: 0.6843
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6309, Validation Loss: 0.6843
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 23/50
# Evaluation Loss: 0.6833
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6316, Validation Loss: 0.6833
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 24/50
# Evaluation Loss: 0.6697
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6307, Validation Loss: 0.6697
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 25/50
# Evaluation Loss: 0.6900
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6287, Validation Loss: 0.6900
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 26/50
# Evaluation Loss: 0.6716
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6287, Validation Loss: 0.6716
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 27/50
# Evaluation Loss: 0.6719
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6276, Validation Loss: 0.6719
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 28/50
# Evaluation Loss: 0.6744
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6260, Validation Loss: 0.6744
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 29/50
# Evaluation Loss: 0.6829
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6256, Validation Loss: 0.6829
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 30/50
# Evaluation Loss: 0.6948
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6251, Validation Loss: 0.6948
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 31/50
# Evaluation Loss: 0.6840
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6239, Validation Loss: 0.6840
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 32/50
# Evaluation Loss: 0.6766
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6227, Validation Loss: 0.6766
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 33/50
# Evaluation Loss: 0.6704
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6223, Validation Loss: 0.6704
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 34/50
# Evaluation Loss: 0.6786
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6207, Validation Loss: 0.6786
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 35/50
# Evaluation Loss: 0.6770
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6208, Validation Loss: 0.6770
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 36/50
# Evaluation Loss: 0.6724
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6194, Validation Loss: 0.6724
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 37/50
# Evaluation Loss: 0.6836
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6195, Validation Loss: 0.6836
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 38/50
# Evaluation Loss: 0.6789
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6186, Validation Loss: 0.6789
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 39/50
# Evaluation Loss: 0.6851
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6179, Validation Loss: 0.6851
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 40/50
# Evaluation Loss: 0.6808
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6167, Validation Loss: 0.6808
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 41/50
# Evaluation Loss: 0.6832
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6158, Validation Loss: 0.6832
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 42/50
# Evaluation Loss: 0.6875
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6160, Validation Loss: 0.6875
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 43/50
# Evaluation Loss: 0.6847
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6145, Validation Loss: 0.6847
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 44/50
# Evaluation Loss: 0.6772
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6143, Validation Loss: 0.6772
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 45/50
# Evaluation Loss: 0.6812
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6124, Validation Loss: 0.6812
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 46/50
# Evaluation Loss: 0.6757
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6115, Validation Loss: 0.6757
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 47/50
# Evaluation Loss: 0.6852
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6107, Validation Loss: 0.6852
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 48/50
# Evaluation Loss: 0.6763
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6105, Validation Loss: 0.6763
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 49/50
# Evaluation Loss: 0.6867
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6094, Validation Loss: 0.6867
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Epoch 50/50
# Evaluation Loss: 0.6710
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# Training Loss: 0.6091, Validation Loss: 0.6710
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Results for Fold 0: Validation Loss = 0.6710, Precision = 0.0000, Recall = 0.0000, F1 Score = 0.0000
# --------------------------------------------------
# ------ Fold 2/5 ------
# Epoch 1/50
# Evaluation Loss: 0.6923
# Precision: 0.3100
# Recall: 0.3407
# F1 Score: 0.3246
# Training Loss: 0.6991, Validation Loss: 0.6923
# Precision: 0.3100, Recall: 0.3407, F1 Score: 0.3246
# Epoch 2/50
# Evaluation Loss: 0.6730
# Precision: 0.2407
# Recall: 0.1429
# F1 Score: 0.1793
# Training Loss: 0.6753, Validation Loss: 0.6730
# Precision: 0.2407, Recall: 0.1429, F1 Score: 0.1793
# Epoch 3/50
# Evaluation Loss: 0.6671
# Precision: 0.3214
# Recall: 0.0989
# F1 Score: 0.1513
# Training Loss: 0.6628, Validation Loss: 0.6671
# Precision: 0.3214, Recall: 0.0989, F1 Score: 0.1513
# Epoch 4/50
# Evaluation Loss: 0.6601
# Precision: 0.3158
# Recall: 0.0659
# F1 Score: 0.1091
# Training Loss: 0.6573, Validation Loss: 0.6601
# Precision: 0.3158, Recall: 0.0659, F1 Score: 0.1091
# Epoch 5/50
# Evaluation Loss: 0.6535
# Precision: 0.4286
# Recall: 0.0659
# F1 Score: 0.1143
# Training Loss: 0.6541, Validation Loss: 0.6535
# Precision: 0.4286, Recall: 0.0659, F1 Score: 0.1143
# Epoch 6/50
# Evaluation Loss: 0.6522
# Precision: 0.4286
# Recall: 0.0659
# F1 Score: 0.1143
# Training Loss: 0.6527, Validation Loss: 0.6522
# Precision: 0.4286, Recall: 0.0659, F1 Score: 0.1143
# Epoch 7/50
# Evaluation Loss: 0.6555
# Precision: 0.3333
# Recall: 0.0330
# F1 Score: 0.0600
# Training Loss: 0.6512, Validation Loss: 0.6555
# Precision: 0.3333, Recall: 0.0330, F1 Score: 0.0600
# Epoch 8/50
# Evaluation Loss: 0.6525
# Precision: 0.4286
# Recall: 0.0330
# F1 Score: 0.0612
# Training Loss: 0.6514, Validation Loss: 0.6525
# Precision: 0.4286, Recall: 0.0330, F1 Score: 0.0612
# Epoch 9/50
# Evaluation Loss: 0.6559
# Precision: 0.4286
# Recall: 0.0330
# F1 Score: 0.0612
# Training Loss: 0.6496, Validation Loss: 0.6559
# Precision: 0.4286, Recall: 0.0330, F1 Score: 0.0612
# Epoch 10/50
# Evaluation Loss: 0.6573
# Precision: 0.3750
# Recall: 0.0330
# F1 Score: 0.0606
# Training Loss: 0.6488, Validation Loss: 0.6573
# Precision: 0.3750, Recall: 0.0330, F1 Score: 0.0606
# Epoch 11/50
# Evaluation Loss: 0.6563
# Precision: 0.4286
# Recall: 0.0330
# F1 Score: 0.0612
# Training Loss: 0.6477, Validation Loss: 0.6563
# Precision: 0.4286, Recall: 0.0330, F1 Score: 0.0612
# Epoch 12/50
# Evaluation Loss: 0.6572
# Precision: 0.4286
# Recall: 0.0330
# F1 Score: 0.0612
# Training Loss: 0.6470, Validation Loss: 0.6572
# Precision: 0.4286, Recall: 0.0330, F1 Score: 0.0612
# Epoch 13/50
# Evaluation Loss: 0.6488
# Precision: 0.4286
# Recall: 0.0330
# F1 Score: 0.0612
# Training Loss: 0.6468, Validation Loss: 0.6488
# Precision: 0.4286, Recall: 0.0330, F1 Score: 0.0612
# Epoch 14/50
# Evaluation Loss: 0.6516
# Precision: 0.4286
# Recall: 0.0330
# F1 Score: 0.0612
# Training Loss: 0.6456, Validation Loss: 0.6516
# Precision: 0.4286, Recall: 0.0330, F1 Score: 0.0612
# Epoch 15/50
# Evaluation Loss: 0.6596
# Precision: 0.3750
# Recall: 0.0330
# F1 Score: 0.0606
# Training Loss: 0.6451, Validation Loss: 0.6596
# Precision: 0.3750, Recall: 0.0330, F1 Score: 0.0606
# Epoch 16/50
# Evaluation Loss: 0.6683
# Precision: 0.3750
# Recall: 0.0330
# F1 Score: 0.0606
# Training Loss: 0.6440, Validation Loss: 0.6683
# Precision: 0.3750, Recall: 0.0330, F1 Score: 0.0606
# Epoch 17/50
# Evaluation Loss: 0.6516
# Precision: 0.3750
# Recall: 0.0330
# F1 Score: 0.0606
# Training Loss: 0.6429, Validation Loss: 0.6516
# Precision: 0.3750, Recall: 0.0330, F1 Score: 0.0606
# Epoch 18/50
# Evaluation Loss: 0.6566
# Precision: 0.3750
# Recall: 0.0330
# F1 Score: 0.0606
# Training Loss: 0.6423, Validation Loss: 0.6566
# Precision: 0.3750, Recall: 0.0330, F1 Score: 0.0606
# Epoch 19/50
# Evaluation Loss: 0.6593
# Precision: 0.4286
# Recall: 0.0330
# F1 Score: 0.0612
# Training Loss: 0.6420, Validation Loss: 0.6593
# Precision: 0.4286, Recall: 0.0330, F1 Score: 0.0612
# Epoch 20/50
# Evaluation Loss: 0.6593
# Precision: 0.3750
# Recall: 0.0330
# F1 Score: 0.0606
# Training Loss: 0.6402, Validation Loss: 0.6593
# Precision: 0.3750, Recall: 0.0330, F1 Score: 0.0606
# Epoch 21/50
# Evaluation Loss: 0.6549
# Precision: 0.3750
# Recall: 0.0330
# F1 Score: 0.0606
# Training Loss: 0.6398, Validation Loss: 0.6549
# Precision: 0.3750, Recall: 0.0330, F1 Score: 0.0606
# Epoch 22/50
# Evaluation Loss: 0.6461
# Precision: 0.3750
# Recall: 0.0330
# F1 Score: 0.0606
# Training Loss: 0.6393, Validation Loss: 0.6461
# Precision: 0.3750, Recall: 0.0330, F1 Score: 0.0606
# Epoch 23/50
# Evaluation Loss: 0.6521
# Precision: 0.3750
# Recall: 0.0330
# F1 Score: 0.0606
# Training Loss: 0.6386, Validation Loss: 0.6521
# Precision: 0.3750, Recall: 0.0330, F1 Score: 0.0606
# Epoch 24/50
# Evaluation Loss: 0.6550
# Precision: 0.3750
# Recall: 0.0330
# F1 Score: 0.0606
# Training Loss: 0.6366, Validation Loss: 0.6550
# Precision: 0.3750, Recall: 0.0330, F1 Score: 0.0606
# Epoch 25/50
# Evaluation Loss: 0.6529
# Precision: 0.3750
# Recall: 0.0330
# F1 Score: 0.0606
# Training Loss: 0.6363, Validation Loss: 0.6529
# Precision: 0.3750, Recall: 0.0330, F1 Score: 0.0606
# Epoch 26/50
# Evaluation Loss: 0.6611
# Precision: 0.3750
# Recall: 0.0330
# F1 Score: 0.0606
# Training Loss: 0.6359, Validation Loss: 0.6611
# Precision: 0.3750, Recall: 0.0330, F1 Score: 0.0606
# Epoch 27/50
# Evaluation Loss: 0.6542
# Precision: 0.3750
# Recall: 0.0330
# F1 Score: 0.0606
# Training Loss: 0.6348, Validation Loss: 0.6542
# Precision: 0.3750, Recall: 0.0330, F1 Score: 0.0606
# Epoch 28/50
# Evaluation Loss: 0.6556
# Precision: 0.3750
# Recall: 0.0330
# F1 Score: 0.0606
# Training Loss: 0.6337, Validation Loss: 0.6556
# Precision: 0.3750, Recall: 0.0330, F1 Score: 0.0606
# Epoch 29/50
# Evaluation Loss: 0.6521
# Precision: 0.3750
# Recall: 0.0330
# F1 Score: 0.0606
# Training Loss: 0.6335, Validation Loss: 0.6521
# Precision: 0.3750, Recall: 0.0330, F1 Score: 0.0606
# Epoch 30/50
# Evaluation Loss: 0.6563
# Precision: 0.3750
# Recall: 0.0330
# F1 Score: 0.0606
# Training Loss: 0.6327, Validation Loss: 0.6563
# Precision: 0.3750, Recall: 0.0330, F1 Score: 0.0606
# Epoch 31/50
# Evaluation Loss: 0.6617
# Precision: 0.3750
# Recall: 0.0330
# F1 Score: 0.0606
# Training Loss: 0.6317, Validation Loss: 0.6617
# Precision: 0.3750, Recall: 0.0330, F1 Score: 0.0606
# Epoch 32/50
# Evaluation Loss: 0.6543
# Precision: 0.3750
# Recall: 0.0330
# F1 Score: 0.0606
# Training Loss: 0.6307, Validation Loss: 0.6543
# Precision: 0.3750, Recall: 0.0330, F1 Score: 0.0606
# Epoch 33/50
# Evaluation Loss: 0.6507
# Precision: 0.3750
# Recall: 0.0330
# F1 Score: 0.0606
# Training Loss: 0.6299, Validation Loss: 0.6507
# Precision: 0.3750, Recall: 0.0330, F1 Score: 0.0606
# Epoch 34/50
# Evaluation Loss: 0.6552
# Precision: 0.3750
# Recall: 0.0330
# F1 Score: 0.0606
# Training Loss: 0.6294, Validation Loss: 0.6552
# Precision: 0.3750, Recall: 0.0330, F1 Score: 0.0606
# Epoch 35/50
# Evaluation Loss: 0.6463
# Precision: 0.3750
# Recall: 0.0330
# F1 Score: 0.0606
# Training Loss: 0.6282, Validation Loss: 0.6463
# Precision: 0.3750, Recall: 0.0330, F1 Score: 0.0606
# Epoch 36/50
# Evaluation Loss: 0.6556
# Precision: 0.3750
# Recall: 0.0330
# F1 Score: 0.0606
# Training Loss: 0.6272, Validation Loss: 0.6556
# Precision: 0.3750, Recall: 0.0330, F1 Score: 0.0606
# Epoch 37/50
# Evaluation Loss: 0.6514
# Precision: 0.3750
# Recall: 0.0330
# F1 Score: 0.0606
# Training Loss: 0.6267, Validation Loss: 0.6514
# Precision: 0.3750, Recall: 0.0330, F1 Score: 0.0606
# Epoch 38/50
# Evaluation Loss: 0.6625
# Precision: 0.3750
# Recall: 0.0330
# F1 Score: 0.0606
# Training Loss: 0.6256, Validation Loss: 0.6625
# Precision: 0.3750, Recall: 0.0330, F1 Score: 0.0606
# Epoch 39/50
# Evaluation Loss: 0.6478
# Precision: 0.3750
# Recall: 0.0330
# F1 Score: 0.0606
# Training Loss: 0.6253, Validation Loss: 0.6478
# Precision: 0.3750, Recall: 0.0330, F1 Score: 0.0606
# Epoch 40/50
# Evaluation Loss: 0.6608
# Precision: 0.3750
# Recall: 0.0330
# F1 Score: 0.0606
# Training Loss: 0.6239, Validation Loss: 0.6608
# Precision: 0.3750, Recall: 0.0330, F1 Score: 0.0606
# Epoch 41/50
# Evaluation Loss: 0.6503
# Precision: 0.3750
# Recall: 0.0330
# F1 Score: 0.0606
# Training Loss: 0.6228, Validation Loss: 0.6503
# Precision: 0.3750, Recall: 0.0330, F1 Score: 0.0606
# Epoch 42/50
# Evaluation Loss: 0.6612
# Precision: 0.3750
# Recall: 0.0330
# F1 Score: 0.0606
# Training Loss: 0.6220, Validation Loss: 0.6612
# Precision: 0.3750, Recall: 0.0330, F1 Score: 0.0606
# Epoch 43/50
# Evaluation Loss: 0.6432
# Precision: 0.3750
# Recall: 0.0330
# F1 Score: 0.0606
# Training Loss: 0.6220, Validation Loss: 0.6432
# Precision: 0.3750, Recall: 0.0330, F1 Score: 0.0606
# Epoch 44/50
# Evaluation Loss: 0.6584
# Precision: 0.3750
# Recall: 0.0330
# F1 Score: 0.0606
# Training Loss: 0.6210, Validation Loss: 0.6584
# Precision: 0.3750, Recall: 0.0330, F1 Score: 0.0606
# Epoch 45/50
# Evaluation Loss: 0.6664
# Precision: 0.3750
# Recall: 0.0330
# F1 Score: 0.0606
# Training Loss: 0.6209, Validation Loss: 0.6664
# Precision: 0.3750, Recall: 0.0330, F1 Score: 0.0606
# Epoch 46/50
# Evaluation Loss: 0.6566
# Precision: 0.3750
# Recall: 0.0330
# F1 Score: 0.0606
# Training Loss: 0.6194, Validation Loss: 0.6566
# Precision: 0.3750, Recall: 0.0330, F1 Score: 0.0606
# Epoch 47/50
# Evaluation Loss: 0.6552
# Precision: 0.3750
# Recall: 0.0330
# F1 Score: 0.0606
# Training Loss: 0.6190, Validation Loss: 0.6552
# Precision: 0.3750, Recall: 0.0330, F1 Score: 0.0606
# Epoch 48/50
# Evaluation Loss: 0.6582
# Precision: 0.3750
# Recall: 0.0330
# F1 Score: 0.0606
# Training Loss: 0.6176, Validation Loss: 0.6582
# Precision: 0.3750, Recall: 0.0330, F1 Score: 0.0606
# Epoch 49/50
# Evaluation Loss: 0.6553
# Precision: 0.3750
# Recall: 0.0330
# F1 Score: 0.0606
# Training Loss: 0.6165, Validation Loss: 0.6553
# Precision: 0.3750, Recall: 0.0330, F1 Score: 0.0606
# Epoch 50/50
# Evaluation Loss: 0.6583
# Precision: 0.3750
# Recall: 0.0330
# F1 Score: 0.0606
# Training Loss: 0.6163, Validation Loss: 0.6583
# Precision: 0.3750, Recall: 0.0330, F1 Score: 0.0606
# Results for Fold 1: Validation Loss = 0.6583, Precision = 0.3750, Recall = 0.0330, F1 Score = 0.0606
# --------------------------------------------------
# ------ Fold 3/5 ------
# Epoch 1/50
# Evaluation Loss: 0.6833
# Precision: 0.2500
# Recall: 0.1609
# F1 Score: 0.1958
# Training Loss: 0.6841, Validation Loss: 0.6833
# Precision: 0.2500, Recall: 0.1609, F1 Score: 0.1958
# Epoch 2/50
# Evaluation Loss: 0.6741
# Precision: 0.2727
# Recall: 0.1034
# F1 Score: 0.1500
# Training Loss: 0.6684, Validation Loss: 0.6741
# Precision: 0.2727, Recall: 0.1034, F1 Score: 0.1500
# Epoch 3/50
# Evaluation Loss: 0.6661
# Precision: 0.2500
# Recall: 0.0690
# F1 Score: 0.1081
# Training Loss: 0.6615, Validation Loss: 0.6661
# Precision: 0.2500, Recall: 0.0690, F1 Score: 0.1081
# Epoch 4/50
# Evaluation Loss: 0.6508
# Precision: 0.1538
# Recall: 0.0230
# F1 Score: 0.0400
# Training Loss: 0.6587, Validation Loss: 0.6508
# Precision: 0.1538, Recall: 0.0230, F1 Score: 0.0400
# Epoch 5/50
# Evaluation Loss: 0.6561
# Precision: 0.1538
# Recall: 0.0230
# F1 Score: 0.0400
# Training Loss: 0.6562, Validation Loss: 0.6561
# Precision: 0.1538, Recall: 0.0230, F1 Score: 0.0400
# Epoch 6/50
# Evaluation Loss: 0.6520
# Precision: 0.1818
# Recall: 0.0230
# F1 Score: 0.0408
# Training Loss: 0.6556, Validation Loss: 0.6520
# Precision: 0.1818, Recall: 0.0230, F1 Score: 0.0408
# Epoch 7/50
# Evaluation Loss: 0.6583
# Precision: 0.1000
# Recall: 0.0115
# F1 Score: 0.0206
# Training Loss: 0.6547, Validation Loss: 0.6583
# Precision: 0.1000, Recall: 0.0115, F1 Score: 0.0206
# Epoch 8/50
# Evaluation Loss: 0.6509
# Precision: 0.1000
# Recall: 0.0115
# F1 Score: 0.0206
# Training Loss: 0.6539, Validation Loss: 0.6509
# Precision: 0.1000, Recall: 0.0115, F1 Score: 0.0206
# Epoch 9/50
# Evaluation Loss: 0.6573
# Precision: 0.1000
# Recall: 0.0115
# F1 Score: 0.0206
# Training Loss: 0.6529, Validation Loss: 0.6573
# Precision: 0.1000, Recall: 0.0115, F1 Score: 0.0206
# Epoch 10/50
# Evaluation Loss: 0.6532
# Precision: 0.1000
# Recall: 0.0115
# F1 Score: 0.0206
# Training Loss: 0.6520, Validation Loss: 0.6532
# Precision: 0.1000, Recall: 0.0115, F1 Score: 0.0206
# Epoch 11/50
# Evaluation Loss: 0.6520
# Precision: 0.1111
# Recall: 0.0115
# F1 Score: 0.0208
# Training Loss: 0.6513, Validation Loss: 0.6520
# Precision: 0.1111, Recall: 0.0115, F1 Score: 0.0208
# Epoch 12/50
# Evaluation Loss: 0.6436
# Precision: 0.1000
# Recall: 0.0115
# F1 Score: 0.0206
# Training Loss: 0.6503, Validation Loss: 0.6436
# Precision: 0.1000, Recall: 0.0115, F1 Score: 0.0206
# Epoch 13/50
# Evaluation Loss: 0.6639
# Precision: 0.1250
# Recall: 0.0115
# F1 Score: 0.0211
# Training Loss: 0.6494, Validation Loss: 0.6639
# Precision: 0.1250, Recall: 0.0115, F1 Score: 0.0211
# Epoch 14/50
# Evaluation Loss: 0.6637
# Precision: 0.1000
# Recall: 0.0115
# F1 Score: 0.0206
# Training Loss: 0.6479, Validation Loss: 0.6637
# Precision: 0.1000, Recall: 0.0115, F1 Score: 0.0206
# Epoch 15/50
# Evaluation Loss: 0.6520
# Precision: 0.1250
# Recall: 0.0115
# F1 Score: 0.0211
# Training Loss: 0.6476, Validation Loss: 0.6520
# Precision: 0.1250, Recall: 0.0115, F1 Score: 0.0211
# Epoch 16/50
# Evaluation Loss: 0.6483
# Precision: 0.1250
# Recall: 0.0115
# F1 Score: 0.0211
# Training Loss: 0.6463, Validation Loss: 0.6483
# Precision: 0.1250, Recall: 0.0115, F1 Score: 0.0211
# Epoch 17/50
# Evaluation Loss: 0.6591
# Precision: 0.1111
# Recall: 0.0115
# F1 Score: 0.0208
# Training Loss: 0.6457, Validation Loss: 0.6591
# Precision: 0.1111, Recall: 0.0115, F1 Score: 0.0208
# Epoch 18/50
# Evaluation Loss: 0.6475
# Precision: 0.1250
# Recall: 0.0115
# F1 Score: 0.0211
# Training Loss: 0.6445, Validation Loss: 0.6475
# Precision: 0.1250, Recall: 0.0115, F1 Score: 0.0211
# Epoch 19/50
# Evaluation Loss: 0.6562
# Precision: 0.1250
# Recall: 0.0115
# F1 Score: 0.0211
# Training Loss: 0.6434, Validation Loss: 0.6562
# Precision: 0.1250, Recall: 0.0115, F1 Score: 0.0211
# Epoch 20/50
# Evaluation Loss: 0.6500
# Precision: 0.1250
# Recall: 0.0115
# F1 Score: 0.0211
# Training Loss: 0.6426, Validation Loss: 0.6500
# Precision: 0.1250, Recall: 0.0115, F1 Score: 0.0211
# Epoch 21/50
# Evaluation Loss: 0.6449
# Precision: 0.1250
# Recall: 0.0115
# F1 Score: 0.0211
# Training Loss: 0.6418, Validation Loss: 0.6449
# Precision: 0.1250, Recall: 0.0115, F1 Score: 0.0211
# Epoch 22/50
# Evaluation Loss: 0.6597
# Precision: 0.1250
# Recall: 0.0115
# F1 Score: 0.0211
# Training Loss: 0.6414, Validation Loss: 0.6597
# Precision: 0.1250, Recall: 0.0115, F1 Score: 0.0211
# Epoch 23/50
# Evaluation Loss: 0.6462
# Precision: 0.1250
# Recall: 0.0115
# F1 Score: 0.0211
# Training Loss: 0.6405, Validation Loss: 0.6462
# Precision: 0.1250, Recall: 0.0115, F1 Score: 0.0211
# Epoch 24/50
# Evaluation Loss: 0.6520
# Precision: 0.1250
# Recall: 0.0115
# F1 Score: 0.0211
# Training Loss: 0.6398, Validation Loss: 0.6520
# Precision: 0.1250, Recall: 0.0115, F1 Score: 0.0211
# Epoch 25/50
# Evaluation Loss: 0.6562
# Precision: 0.1250
# Recall: 0.0115
# F1 Score: 0.0211
# Training Loss: 0.6386, Validation Loss: 0.6562
# Precision: 0.1250, Recall: 0.0115, F1 Score: 0.0211
# Epoch 26/50
# Evaluation Loss: 0.6507
# Precision: 0.1250
# Recall: 0.0115
# F1 Score: 0.0211
# Training Loss: 0.6374, Validation Loss: 0.6507
# Precision: 0.1250, Recall: 0.0115, F1 Score: 0.0211
# Epoch 27/50
# Evaluation Loss: 0.6644
# Precision: 0.1250
# Recall: 0.0115
# F1 Score: 0.0211
# Training Loss: 0.6367, Validation Loss: 0.6644
# Precision: 0.1250, Recall: 0.0115, F1 Score: 0.0211
# Epoch 28/50
# Evaluation Loss: 0.6574
# Precision: 0.1250
# Recall: 0.0115
# F1 Score: 0.0211
# Training Loss: 0.6357, Validation Loss: 0.6574
# Precision: 0.1250, Recall: 0.0115, F1 Score: 0.0211
# Epoch 29/50
# Evaluation Loss: 0.6498
# Precision: 0.1250
# Recall: 0.0115
# F1 Score: 0.0211
# Training Loss: 0.6350, Validation Loss: 0.6498
# Precision: 0.1250, Recall: 0.0115, F1 Score: 0.0211
# Epoch 30/50
# Evaluation Loss: 0.6442
# Precision: 0.1250
# Recall: 0.0115
# F1 Score: 0.0211
# Training Loss: 0.6344, Validation Loss: 0.6442
# Precision: 0.1250, Recall: 0.0115, F1 Score: 0.0211
# Epoch 31/50
# Evaluation Loss: 0.6462
# Precision: 0.1250
# Recall: 0.0115
# F1 Score: 0.0211
# Training Loss: 0.6329, Validation Loss: 0.6462
# Precision: 0.1250, Recall: 0.0115, F1 Score: 0.0211
# Epoch 32/50
# Evaluation Loss: 0.6567
# Precision: 0.1250
# Recall: 0.0115
# F1 Score: 0.0211
# Training Loss: 0.6329, Validation Loss: 0.6567
# Precision: 0.1250, Recall: 0.0115, F1 Score: 0.0211
# Epoch 33/50
# Evaluation Loss: 0.6557
# Precision: 0.1250
# Recall: 0.0115
# F1 Score: 0.0211
# Training Loss: 0.6316, Validation Loss: 0.6557
# Precision: 0.1250, Recall: 0.0115, F1 Score: 0.0211
# Epoch 34/50
# Evaluation Loss: 0.6505
# Precision: 0.1250
# Recall: 0.0115
# F1 Score: 0.0211
# Training Loss: 0.6310, Validation Loss: 0.6505
# Precision: 0.1250, Recall: 0.0115, F1 Score: 0.0211
# Epoch 35/50
# Evaluation Loss: 0.6556
# Precision: 0.1250
# Recall: 0.0115
# F1 Score: 0.0211
# Training Loss: 0.6299, Validation Loss: 0.6556
# Precision: 0.1250, Recall: 0.0115, F1 Score: 0.0211
# Epoch 36/50
# Evaluation Loss: 0.6537
# Precision: 0.1250
# Recall: 0.0115
# F1 Score: 0.0211
# Training Loss: 0.6290, Validation Loss: 0.6537
# Precision: 0.1250, Recall: 0.0115, F1 Score: 0.0211
# Epoch 37/50
# Evaluation Loss: 0.6576
# Precision: 0.1250
# Recall: 0.0115
# F1 Score: 0.0211
# Training Loss: 0.6284, Validation Loss: 0.6576
# Precision: 0.1250, Recall: 0.0115, F1 Score: 0.0211
# Epoch 38/50
# Evaluation Loss: 0.6543
# Precision: 0.1250
# Recall: 0.0115
# F1 Score: 0.0211
# Training Loss: 0.6270, Validation Loss: 0.6543
# Precision: 0.1250, Recall: 0.0115, F1 Score: 0.0211
# Epoch 39/50
# Evaluation Loss: 0.6557
# Precision: 0.1250
# Recall: 0.0115
# F1 Score: 0.0211
# Training Loss: 0.6267, Validation Loss: 0.6557
# Precision: 0.1250, Recall: 0.0115, F1 Score: 0.0211
# Epoch 40/50
# Evaluation Loss: 0.6603
# Precision: 0.2222
# Recall: 0.0230
# F1 Score: 0.0417
# Training Loss: 0.6259, Validation Loss: 0.6603
# Precision: 0.2222, Recall: 0.0230, F1 Score: 0.0417
# Epoch 41/50
# Evaluation Loss: 0.6598
# Precision: 0.1250
# Recall: 0.0115
# F1 Score: 0.0211
# Training Loss: 0.6254, Validation Loss: 0.6598
# Precision: 0.1250, Recall: 0.0115, F1 Score: 0.0211
# Epoch 42/50
# Evaluation Loss: 0.6523
# Precision: 0.1250
# Recall: 0.0115
# F1 Score: 0.0211
# Training Loss: 0.6239, Validation Loss: 0.6523
# Precision: 0.1250, Recall: 0.0115, F1 Score: 0.0211
# Epoch 43/50
# Evaluation Loss: 0.6554
# Precision: 0.2222
# Recall: 0.0230
# F1 Score: 0.0417
# Training Loss: 0.6230, Validation Loss: 0.6554
# Precision: 0.2222, Recall: 0.0230, F1 Score: 0.0417
# Epoch 44/50
# Evaluation Loss: 0.6535
# Precision: 0.2222
# Recall: 0.0230
# F1 Score: 0.0417
# Training Loss: 0.6226, Validation Loss: 0.6535
# Precision: 0.2222, Recall: 0.0230, F1 Score: 0.0417
# Epoch 45/50
# Evaluation Loss: 0.6590
# Precision: 0.2222
# Recall: 0.0230
# F1 Score: 0.0417
# Training Loss: 0.6214, Validation Loss: 0.6590
# Precision: 0.2222, Recall: 0.0230, F1 Score: 0.0417
# Epoch 46/50
# Evaluation Loss: 0.6490
# Precision: 0.2222
# Recall: 0.0230
# F1 Score: 0.0417
# Training Loss: 0.6213, Validation Loss: 0.6490
# Precision: 0.2222, Recall: 0.0230, F1 Score: 0.0417
# Epoch 47/50
# Evaluation Loss: 0.6532
# Precision: 0.2222
# Recall: 0.0230
# F1 Score: 0.0417
# Training Loss: 0.6195, Validation Loss: 0.6532
# Precision: 0.2222, Recall: 0.0230, F1 Score: 0.0417
# Epoch 48/50
# Evaluation Loss: 0.6585
# Precision: 0.2222
# Recall: 0.0230
# F1 Score: 0.0417
# Training Loss: 0.6191, Validation Loss: 0.6585
# Precision: 0.2222, Recall: 0.0230, F1 Score: 0.0417
# Epoch 49/50
# Evaluation Loss: 0.6555
# Precision: 0.2222
# Recall: 0.0230
# F1 Score: 0.0417
# Training Loss: 0.6179, Validation Loss: 0.6555
# Precision: 0.2222, Recall: 0.0230, F1 Score: 0.0417
# Epoch 50/50
# Evaluation Loss: 0.6583
# Precision: 0.2222
# Recall: 0.0230
# F1 Score: 0.0417
# Training Loss: 0.6170, Validation Loss: 0.6583
# Precision: 0.2222, Recall: 0.0230, F1 Score: 0.0417
# Results for Fold 2: Validation Loss = 0.6583, Precision = 0.2222, Recall = 0.0230, F1 Score = 0.0417
# --------------------------------------------------
# ------ Fold 4/5 ------
# Epoch 1/50
# Evaluation Loss: 0.6498
# Precision: 0.5238
# Recall: 0.1134
# F1 Score: 0.1864
# Training Loss: 0.6592, Validation Loss: 0.6498
# Precision: 0.5238, Recall: 0.1134, F1 Score: 0.1864
# Epoch 2/50
# Evaluation Loss: 0.6420
# Precision: 0.5000
# Recall: 0.0619
# F1 Score: 0.1101
# Training Loss: 0.6539, Validation Loss: 0.6420
# Precision: 0.5000, Recall: 0.0619, F1 Score: 0.1101
# Epoch 3/50
# Evaluation Loss: 0.6561
# Precision: 0.5556
# Recall: 0.0515
# F1 Score: 0.0943
# Training Loss: 0.6515, Validation Loss: 0.6561
# Precision: 0.5556, Recall: 0.0515, F1 Score: 0.0943
# Epoch 4/50
# Evaluation Loss: 0.6521
# Precision: 0.7143
# Recall: 0.0515
# F1 Score: 0.0962
# Training Loss: 0.6507, Validation Loss: 0.6521
# Precision: 0.7143, Recall: 0.0515, F1 Score: 0.0962
# Epoch 5/50
# Evaluation Loss: 0.6500
# Precision: 0.7143
# Recall: 0.0515
# F1 Score: 0.0962
# Training Loss: 0.6500, Validation Loss: 0.6500
# Precision: 0.7143, Recall: 0.0515, F1 Score: 0.0962
# Epoch 6/50
# Evaluation Loss: 0.6441
# Precision: 0.7143
# Recall: 0.0515
# F1 Score: 0.0962
# Training Loss: 0.6487, Validation Loss: 0.6441
# Precision: 0.7143, Recall: 0.0515, F1 Score: 0.0962
# Epoch 7/50
# Evaluation Loss: 0.6424
# Precision: 0.7143
# Recall: 0.0515
# F1 Score: 0.0962
# Training Loss: 0.6478, Validation Loss: 0.6424
# Precision: 0.7143, Recall: 0.0515, F1 Score: 0.0962
# Epoch 8/50
# Evaluation Loss: 0.6550
# Precision: 0.7143
# Recall: 0.0515
# F1 Score: 0.0962
# Training Loss: 0.6467, Validation Loss: 0.6550
# Precision: 0.7143, Recall: 0.0515, F1 Score: 0.0962
# Epoch 9/50
# Evaluation Loss: 0.6517
# Precision: 0.7143
# Recall: 0.0515
# F1 Score: 0.0962
# Training Loss: 0.6459, Validation Loss: 0.6517
# Precision: 0.7143, Recall: 0.0515, F1 Score: 0.0962
# Epoch 10/50
# Evaluation Loss: 0.6571
# Precision: 0.7143
# Recall: 0.0515
# F1 Score: 0.0962
# Training Loss: 0.6445, Validation Loss: 0.6571
# Precision: 0.7143, Recall: 0.0515, F1 Score: 0.0962
# Epoch 11/50
# Evaluation Loss: 0.6489
# Precision: 0.7143
# Recall: 0.0515
# F1 Score: 0.0962
# Training Loss: 0.6442, Validation Loss: 0.6489
# Precision: 0.7143, Recall: 0.0515, F1 Score: 0.0962
# Epoch 12/50
# Evaluation Loss: 0.6407
# Precision: 0.7143
# Recall: 0.0515
# F1 Score: 0.0962
# Training Loss: 0.6429, Validation Loss: 0.6407
# Precision: 0.7143, Recall: 0.0515, F1 Score: 0.0962
# Epoch 13/50
# Evaluation Loss: 0.6420
# Precision: 0.7143
# Recall: 0.0515
# F1 Score: 0.0962
# Training Loss: 0.6422, Validation Loss: 0.6420
# Precision: 0.7143, Recall: 0.0515, F1 Score: 0.0962
# Epoch 14/50
# Evaluation Loss: 0.6466
# Precision: 0.7143
# Recall: 0.0515
# F1 Score: 0.0962
# Training Loss: 0.6413, Validation Loss: 0.6466
# Precision: 0.7143, Recall: 0.0515, F1 Score: 0.0962
# Epoch 15/50
# Evaluation Loss: 0.6453
# Precision: 0.7143
# Recall: 0.0515
# F1 Score: 0.0962
# Training Loss: 0.6410, Validation Loss: 0.6453
# Precision: 0.7143, Recall: 0.0515, F1 Score: 0.0962
# Epoch 16/50
# Evaluation Loss: 0.6480
# Precision: 0.7143
# Recall: 0.0515
# F1 Score: 0.0962
# Training Loss: 0.6396, Validation Loss: 0.6480
# Precision: 0.7143, Recall: 0.0515, F1 Score: 0.0962
# Epoch 17/50
# Evaluation Loss: 0.6444
# Precision: 0.7143
# Recall: 0.0515
# F1 Score: 0.0962
# Training Loss: 0.6383, Validation Loss: 0.6444
# Precision: 0.7143, Recall: 0.0515, F1 Score: 0.0962
# Epoch 18/50
# Evaluation Loss: 0.6444
# Precision: 0.7143
# Recall: 0.0515
# F1 Score: 0.0962
# Training Loss: 0.6375, Validation Loss: 0.6444
# Precision: 0.7143, Recall: 0.0515, F1 Score: 0.0962
# Epoch 19/50
# Evaluation Loss: 0.6585
# Precision: 0.7143
# Recall: 0.0515
# F1 Score: 0.0962
# Training Loss: 0.6368, Validation Loss: 0.6585
# Precision: 0.7143, Recall: 0.0515, F1 Score: 0.0962
# Epoch 20/50
# Evaluation Loss: 0.6390
# Precision: 0.7143
# Recall: 0.0515
# F1 Score: 0.0962
# Training Loss: 0.6362, Validation Loss: 0.6390
# Precision: 0.7143, Recall: 0.0515, F1 Score: 0.0962
# Epoch 21/50
# Evaluation Loss: 0.6395
# Precision: 0.7143
# Recall: 0.0515
# F1 Score: 0.0962
# Training Loss: 0.6349, Validation Loss: 0.6395
# Precision: 0.7143, Recall: 0.0515, F1 Score: 0.0962
# Epoch 22/50
# Evaluation Loss: 0.6432
# Precision: 0.7143
# Recall: 0.0515
# F1 Score: 0.0962
# Training Loss: 0.6341, Validation Loss: 0.6432
# Precision: 0.7143, Recall: 0.0515, F1 Score: 0.0962
# Epoch 23/50
# Evaluation Loss: 0.6509
# Precision: 0.7143
# Recall: 0.0515
# F1 Score: 0.0962
# Training Loss: 0.6340, Validation Loss: 0.6509
# Precision: 0.7143, Recall: 0.0515, F1 Score: 0.0962
# Epoch 24/50
# Evaluation Loss: 0.6475
# Precision: 0.7143
# Recall: 0.0515
# F1 Score: 0.0962
# Training Loss: 0.6323, Validation Loss: 0.6475
# Precision: 0.7143, Recall: 0.0515, F1 Score: 0.0962
# Epoch 25/50
# Evaluation Loss: 0.6637
# Precision: 0.7143
# Recall: 0.0515
# F1 Score: 0.0962
# Training Loss: 0.6323, Validation Loss: 0.6637
# Precision: 0.7143, Recall: 0.0515, F1 Score: 0.0962
# Epoch 26/50
# Evaluation Loss: 0.6484
# Precision: 0.7143
# Recall: 0.0515
# F1 Score: 0.0962
# Training Loss: 0.6307, Validation Loss: 0.6484
# Precision: 0.7143, Recall: 0.0515, F1 Score: 0.0962
# Epoch 27/50
# Evaluation Loss: 0.6456
# Precision: 0.7143
# Recall: 0.0515
# F1 Score: 0.0962
# Training Loss: 0.6301, Validation Loss: 0.6456
# Precision: 0.7143, Recall: 0.0515, F1 Score: 0.0962
# Epoch 28/50
# Evaluation Loss: 0.6565
# Precision: 0.7143
# Recall: 0.0515
# F1 Score: 0.0962
# Training Loss: 0.6291, Validation Loss: 0.6565
# Precision: 0.7143, Recall: 0.0515, F1 Score: 0.0962
# Epoch 29/50
# Evaluation Loss: 0.6485
# Precision: 0.7143
# Recall: 0.0515
# F1 Score: 0.0962
# Training Loss: 0.6281, Validation Loss: 0.6485
# Precision: 0.7143, Recall: 0.0515, F1 Score: 0.0962
# Epoch 30/50
# Evaluation Loss: 0.6464
# Precision: 0.7143
# Recall: 0.0515
# F1 Score: 0.0962
# Training Loss: 0.6275, Validation Loss: 0.6464
# Precision: 0.7143, Recall: 0.0515, F1 Score: 0.0962
# Epoch 31/50
# Evaluation Loss: 0.6394
# Precision: 0.7143
# Recall: 0.0515
# F1 Score: 0.0962
# Training Loss: 0.6263, Validation Loss: 0.6394
# Precision: 0.7143, Recall: 0.0515, F1 Score: 0.0962
# Epoch 32/50
# Evaluation Loss: 0.6543
# Precision: 0.7143
# Recall: 0.0515
# F1 Score: 0.0962
# Training Loss: 0.6261, Validation Loss: 0.6543
# Precision: 0.7143, Recall: 0.0515, F1 Score: 0.0962
# Epoch 33/50
# Evaluation Loss: 0.6466
# Precision: 0.6667
# Recall: 0.0412
# F1 Score: 0.0777
# Training Loss: 0.6249, Validation Loss: 0.6466
# Precision: 0.6667, Recall: 0.0412, F1 Score: 0.0777
# Epoch 34/50
# Evaluation Loss: 0.6531
# Precision: 0.7143
# Recall: 0.0515
# F1 Score: 0.0962
# Training Loss: 0.6241, Validation Loss: 0.6531
# Precision: 0.7143, Recall: 0.0515, F1 Score: 0.0962
# Epoch 35/50
# Evaluation Loss: 0.6480
# Precision: 0.7143
# Recall: 0.0515
# F1 Score: 0.0962
# Training Loss: 0.6234, Validation Loss: 0.6480
# Precision: 0.7143, Recall: 0.0515, F1 Score: 0.0962
# Epoch 36/50
# Evaluation Loss: 0.6432
# Precision: 0.7143
# Recall: 0.0515
# F1 Score: 0.0962
# Training Loss: 0.6230, Validation Loss: 0.6432
# Precision: 0.7143, Recall: 0.0515, F1 Score: 0.0962
# Epoch 37/50
# Evaluation Loss: 0.6501
# Precision: 0.7143
# Recall: 0.0515
# F1 Score: 0.0962
# Training Loss: 0.6215, Validation Loss: 0.6501
# Precision: 0.7143, Recall: 0.0515, F1 Score: 0.0962
# Epoch 38/50
# Evaluation Loss: 0.6487
# Precision: 0.7143
# Recall: 0.0515
# F1 Score: 0.0962
# Training Loss: 0.6201, Validation Loss: 0.6487
# Precision: 0.7143, Recall: 0.0515, F1 Score: 0.0962
# Epoch 39/50
# Evaluation Loss: 0.6421
# Precision: 0.6667
# Recall: 0.0412
# F1 Score: 0.0777
# Training Loss: 0.6195, Validation Loss: 0.6421
# Precision: 0.6667, Recall: 0.0412, F1 Score: 0.0777
# Epoch 40/50
# Evaluation Loss: 0.6516
# Precision: 0.6667
# Recall: 0.0412
# F1 Score: 0.0777
# Training Loss: 0.6189, Validation Loss: 0.6516
# Precision: 0.6667, Recall: 0.0412, F1 Score: 0.0777
# Epoch 41/50
# Evaluation Loss: 0.6522
# Precision: 0.6667
# Recall: 0.0412
# F1 Score: 0.0777
# Training Loss: 0.6180, Validation Loss: 0.6522
# Precision: 0.6667, Recall: 0.0412, F1 Score: 0.0777
# Epoch 42/50
# Evaluation Loss: 0.6535
# Precision: 0.6667
# Recall: 0.0412
# F1 Score: 0.0777
# Training Loss: 0.6167, Validation Loss: 0.6535
# Precision: 0.6667, Recall: 0.0412, F1 Score: 0.0777
# Epoch 43/50
# Evaluation Loss: 0.6483
# Precision: 0.6667
# Recall: 0.0412
# F1 Score: 0.0777
# Training Loss: 0.6163, Validation Loss: 0.6483
# Precision: 0.6667, Recall: 0.0412, F1 Score: 0.0777
# Epoch 44/50
# Evaluation Loss: 0.6443
# Precision: 0.6667
# Recall: 0.0412
# F1 Score: 0.0777
# Training Loss: 0.6155, Validation Loss: 0.6443
# Precision: 0.6667, Recall: 0.0412, F1 Score: 0.0777
# Epoch 45/50
# Evaluation Loss: 0.6429
# Precision: 0.6667
# Recall: 0.0412
# F1 Score: 0.0777
# Training Loss: 0.6150, Validation Loss: 0.6429
# Precision: 0.6667, Recall: 0.0412, F1 Score: 0.0777
# Epoch 46/50
# Evaluation Loss: 0.6593
# Precision: 0.6667
# Recall: 0.0412
# F1 Score: 0.0777
# Training Loss: 0.6133, Validation Loss: 0.6593
# Precision: 0.6667, Recall: 0.0412, F1 Score: 0.0777
# Epoch 47/50
# Evaluation Loss: 0.6514
# Precision: 0.6667
# Recall: 0.0412
# F1 Score: 0.0777
# Training Loss: 0.6129, Validation Loss: 0.6514
# Precision: 0.6667, Recall: 0.0412, F1 Score: 0.0777
# Epoch 48/50
# Evaluation Loss: 0.6522
# Precision: 0.6667
# Recall: 0.0412
# F1 Score: 0.0777
# Training Loss: 0.6117, Validation Loss: 0.6522
# Precision: 0.6667, Recall: 0.0412, F1 Score: 0.0777
# Epoch 49/50
# Evaluation Loss: 0.6458
# Precision: 0.6667
# Recall: 0.0412
# F1 Score: 0.0777
# Training Loss: 0.6118, Validation Loss: 0.6458
# Precision: 0.6667, Recall: 0.0412, F1 Score: 0.0777
# Epoch 50/50
# Evaluation Loss: 0.6467
# Precision: 0.6667
# Recall: 0.0412
# F1 Score: 0.0777
# Training Loss: 0.6106, Validation Loss: 0.6467
# Precision: 0.6667, Recall: 0.0412, F1 Score: 0.0777
# Results for Fold 3: Validation Loss = 0.6467, Precision = 0.6667, Recall = 0.0412, F1 Score = 0.0777
# --------------------------------------------------
# ------ Fold 5/5 ------
# Epoch 1/50
# Evaluation Loss: 0.6224
# Precision: 0.4615
# Recall: 0.0690
# F1 Score: 0.1200
# Training Loss: 0.6544, Validation Loss: 0.6224
# Precision: 0.4615, Recall: 0.0690, F1 Score: 0.1200
# Epoch 2/50
# Evaluation Loss: 0.6187
# Precision: 0.5714
# Recall: 0.0460
# F1 Score: 0.0851
# Training Loss: 0.6510, Validation Loss: 0.6187
# Precision: 0.5714, Recall: 0.0460, F1 Score: 0.0851
# Epoch 3/50
# Evaluation Loss: 0.6153
# Precision: 0.5000
# Recall: 0.0345
# F1 Score: 0.0645
# Training Loss: 0.6499, Validation Loss: 0.6153
# Precision: 0.5000, Recall: 0.0345, F1 Score: 0.0645
# Epoch 4/50
# Evaluation Loss: 0.6322
# Precision: 0.5000
# Recall: 0.0345
# F1 Score: 0.0645
# Training Loss: 0.6479, Validation Loss: 0.6322
# Precision: 0.5000, Recall: 0.0345, F1 Score: 0.0645
# Epoch 5/50
# Evaluation Loss: 0.6081
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6471, Validation Loss: 0.6081
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 6/50
# Evaluation Loss: 0.6191
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6462, Validation Loss: 0.6191
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 7/50
# Evaluation Loss: 0.6187
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6455, Validation Loss: 0.6187
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 8/50
# Evaluation Loss: 0.6291
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6441, Validation Loss: 0.6291
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 9/50
# Evaluation Loss: 0.6176
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6441, Validation Loss: 0.6176
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 10/50
# Evaluation Loss: 0.6159
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6433, Validation Loss: 0.6159
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 11/50
# Evaluation Loss: 0.6150
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6421, Validation Loss: 0.6150
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 12/50
# Evaluation Loss: 0.6123
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6413, Validation Loss: 0.6123
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 13/50
# Evaluation Loss: 0.6136
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6406, Validation Loss: 0.6136
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 14/50
# Evaluation Loss: 0.6199
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6391, Validation Loss: 0.6199
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 15/50
# Evaluation Loss: 0.6111
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6381, Validation Loss: 0.6111
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 16/50
# Evaluation Loss: 0.6156
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6377, Validation Loss: 0.6156
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 17/50
# Evaluation Loss: 0.6132
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6362, Validation Loss: 0.6132
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 18/50
# Evaluation Loss: 0.6228
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6357, Validation Loss: 0.6228
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 19/50
# Evaluation Loss: 0.6198
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6345, Validation Loss: 0.6198
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 20/50
# Evaluation Loss: 0.6191
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6343, Validation Loss: 0.6191
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 21/50
# Evaluation Loss: 0.6107
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6330, Validation Loss: 0.6107
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 22/50
# Evaluation Loss: 0.6199
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6326, Validation Loss: 0.6199
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 23/50
# Evaluation Loss: 0.6183
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6315, Validation Loss: 0.6183
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 24/50
# Evaluation Loss: 0.6206
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6303, Validation Loss: 0.6206
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 25/50
# Evaluation Loss: 0.6165
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6293, Validation Loss: 0.6165
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 26/50
# Evaluation Loss: 0.6246
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6288, Validation Loss: 0.6246
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 27/50
# Evaluation Loss: 0.6206
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6280, Validation Loss: 0.6206
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 28/50
# Evaluation Loss: 0.6098
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6272, Validation Loss: 0.6098
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 29/50
# Evaluation Loss: 0.6274
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6258, Validation Loss: 0.6274
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 30/50
# Evaluation Loss: 0.6284
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6250, Validation Loss: 0.6284
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 31/50
# Evaluation Loss: 0.6122
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6246, Validation Loss: 0.6122
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 32/50
# Evaluation Loss: 0.6194
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6235, Validation Loss: 0.6194
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 33/50
# Evaluation Loss: 0.6149
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6226, Validation Loss: 0.6149
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 34/50
# Evaluation Loss: 0.6227
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6219, Validation Loss: 0.6227
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 35/50
# Evaluation Loss: 0.6183
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6206, Validation Loss: 0.6183
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 36/50
# Evaluation Loss: 0.6189
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6206, Validation Loss: 0.6189
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 37/50
# Evaluation Loss: 0.6174
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6190, Validation Loss: 0.6174
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 38/50
# Evaluation Loss: 0.6217
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6185, Validation Loss: 0.6217
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 39/50
# Evaluation Loss: 0.6248
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6177, Validation Loss: 0.6248
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 40/50
# Evaluation Loss: 0.6206
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6169, Validation Loss: 0.6206
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 41/50
# Evaluation Loss: 0.6200
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6160, Validation Loss: 0.6200
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 42/50
# Evaluation Loss: 0.6223
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6150, Validation Loss: 0.6223
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 43/50
# Evaluation Loss: 0.6125
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6146, Validation Loss: 0.6125
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 44/50
# Evaluation Loss: 0.6091
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6137, Validation Loss: 0.6091
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 45/50
# Evaluation Loss: 0.6240
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6129, Validation Loss: 0.6240
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 46/50
# Evaluation Loss: 0.6167
# Precision: 0.5000
# Recall: 0.0345
# F1 Score: 0.0645
# Training Loss: 0.6117, Validation Loss: 0.6167
# Precision: 0.5000, Recall: 0.0345, F1 Score: 0.0645
# Epoch 47/50
# Evaluation Loss: 0.6236
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6114, Validation Loss: 0.6236
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 48/50
# Evaluation Loss: 0.6162
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6102, Validation Loss: 0.6162
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Epoch 49/50
# Evaluation Loss: 0.6157
# Precision: 0.5000
# Recall: 0.0345
# F1 Score: 0.0645
# Training Loss: 0.6098, Validation Loss: 0.6157
# Precision: 0.5000, Recall: 0.0345, F1 Score: 0.0645
# Epoch 50/50
# Evaluation Loss: 0.6212
# Precision: 0.4000
# Recall: 0.0230
# F1 Score: 0.0435
# Training Loss: 0.6091, Validation Loss: 0.6212
# Precision: 0.4000, Recall: 0.0230, F1 Score: 0.0435
# Results for Fold 4: Validation Loss = 0.6212, Precision = 0.4000, Recall = 0.0230, F1 Score = 0.0435
# --------------------------------------------------
#
# K-Fold Cross-Validation Results:
# Average Loss: 0.6511
# Average Precision: 0.3328
# Average Recall: 0.0240
# Average F1 Score: 0.0447
# F1 scores per fold saved to results/simulParallel-Xie-F1_scores.npy
# Device: cpu
# Testing the model on the test set...
# Test Loss: 0.6708
# Test Precision: 0.3077
# Test Recall: 0.2388
# Test F1 Score: 0.2689
