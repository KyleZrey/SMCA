# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torch.nn.init as init
from torch.utils.data import DataLoader, Dataset
from torch.nn.utils.rnn import pad_sequence

# %%
# Set float32 matmul precision for Tensor Cores
torch.set_float32_matmul_precision('medium')

# %%
class MultimodalDataset(Dataset):
    def __init__(self, label_df, text_dir, audio_dir, video_dir):
        self.label_df = label_df
        self.text_dir = text_dir
        self.audio_dir = audio_dir
        self.video_dir = video_dir

        # List to store missing files
        self.missing_files = []

        # Filter out entries with missing files
        self.valid_indices = self._filter_valid_files()

    def _filter_valid_files(self):
        valid_indices = []
        for idx in range(len(self.label_df)):
            imdbid = self.label_df.iloc[idx]['IMDBid']

            text_path = os.path.join(self.text_dir, f"{imdbid}.npy")
            audio_path = os.path.join(self.audio_dir, f"feature_{imdbid}.npy")
            video_path = os.path.join(self.video_dir, f"{imdbid}_features.npy")

            missing_files = []
            if not os.path.exists(text_path):
                missing_files.append(text_path)
            if not os.path.exists(audio_path):
                missing_files.append(audio_path)
            if not os.path.exists(video_path):
                missing_files.append(video_path)

            if missing_files:
                self.missing_files.append({
                    'IMDBid': imdbid,
                    'missing_files': missing_files,
                    'missing_count': len(missing_files)
                })
            else:
                valid_indices.append(idx)

        # Print missing files after checking all
        if self.missing_files:
            print("Missing files:")
            total_missing_files = 0
            for item in self.missing_files:
                print(f"IMDBid: {item['IMDBid']} (Missing {item['missing_count']} files)")
                total_missing_files += item['missing_count']
                for file in item['missing_files']:
                    print(f"  Missing file: {file}")
            print(f"Total missing files: {total_missing_files}")
            print(f"Total IMDB IDs with missing files: {len(self.missing_files)}")
        else:
            print("No missing files.")

        return valid_indices

    def __len__(self):
        return len(self.valid_indices)

    def __getitem__(self, idx):
        # Get the original index from the filtered valid indices
        original_idx = self.valid_indices[idx]
        imdbid = self.label_df.iloc[original_idx]['IMDBid']
        label = self.label_df.iloc[original_idx]['Label']

        text_path = os.path.join(self.text_dir, f"{imdbid}.npy")
        audio_path = os.path.join(self.audio_dir, f"feature_{imdbid}.npy")
        video_path = os.path.join(self.video_dir, f"{imdbid}_features.npy")

        text_data = np.load(text_path) if os.path.exists(text_path) else np.zeros((1024,))
        audio_data = np.load(audio_path) if os.path.exists(audio_path) else np.zeros((1, 197, 768))
        video_data = np.load(video_path) if os.path.exists(video_path) else np.zeros((95, 768))

        # Convert to torch tensors
        text_data = torch.tensor(text_data, dtype=torch.float32)
        audio_data = torch.tensor(audio_data, dtype=torch.float32)
        video_data = torch.tensor(video_data, dtype=torch.float32)

        return text_data, audio_data, video_data, label

# %%
# Define label mapping
label_map = {'red': 0, 'green': 1}  # Add other labels as needed

def collate_fn(batch):
    text_data, audio_data, video_data, labels = zip(*batch)

    # Convert lists to tensors
    text_data = torch.stack(text_data)
    audio_data = torch.stack(audio_data)

    # Padding for video data
    video_lengths = [v.size(0) for v in video_data]
    max_length = max(video_lengths)
    video_data_padded = torch.stack([torch.cat([v, torch.zeros(max_length - v.size(0), v.size(1))]) for v in video_data])

    # Convert labels to tensor using label_map
    try:
        labels = torch.tensor([label_map[label] for label in labels], dtype=torch.long)  # Ensure labels are integers
    except KeyError as e:
        print(f"Error: Label '{e}' not found in label_map.")
        raise

    return text_data, audio_data, video_data_padded, labels

# %%
# Load the labels DataFrame
label_df = pd.read_excel('C:\\Users\\edjin\\OneDrive\\Documents\\Programming Files\\Thesis\\SMCA\\misc\\MM-Trailer_dataset.xlsx')

# Splitting data into training and remaining sets
train_df, remaining_df = train_test_split(label_df, test_size=0.3, random_state=42)

# Further splitting remaining set into validation and test sets
val_df, test_df = train_test_split(remaining_df, test_size=0.5, random_state=42)

# Directory paths
text_dir = 'C:\\Users\\edjin\\OneDrive\\Documents\\Programming Files\\Thesis\\SMCA\\misc\\textStream_BERT\\feature_vectors\\feature_vectors'
audio_dir = 'C:\\Users\\edjin\\OneDrive\\Documents\\Programming Files\\Thesis\\SMCA\\misc\\audio_fe\\logmel_spectrograms'
video_dir = 'C:\\Users\\edjin\\OneDrive\\Documents\\Programming Files\\Thesis\\SMCA\\misc\\visualStream_ViT\\feature_vectors'

# Create datasets
train_dataset = MultimodalDataset(train_df, text_dir, audio_dir, video_dir)
val_dataset = MultimodalDataset(val_df, text_dir, audio_dir, video_dir)
test_dataset = MultimodalDataset(test_df, text_dir, audio_dir, video_dir)

# Create DataLoaders
train_dataloader = DataLoader(train_dataset, batch_size=8, shuffle=True, num_workers=0, collate_fn=collate_fn)
val_dataloader = DataLoader(val_dataset, batch_size=8, shuffle=False, num_workers=0, collate_fn=collate_fn)
test_dataloader = DataLoader(test_dataset, batch_size=8, shuffle=False, num_workers=0, collate_fn=collate_fn)
# Out:
# Missing files:
# IMDBid: tt2494280 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt2494280.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt2494280.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt2494280_features.npy
# IMDBid: tt1724962 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt1724962.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt1724962.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt1724962_features.npy
# IMDBid: tt1152836 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt1152836.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt1152836.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt1152836_features.npy
# IMDBid: tt0389790 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt0389790.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt0389790.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt0389790_features.npy
# IMDBid: tt3053228 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt3053228.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt3053228.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt3053228_features.npy
# IMDBid: tt1045778 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt1045778.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt1045778.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt1045778_features.npy
# IMDBid: tt1758795 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt1758795.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt1758795.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt1758795_features.npy
# IMDBid: tt0099385 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt0099385.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt0099385.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt0099385_features.npy
# IMDBid: tt2917484 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt2917484.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt2917484.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt2917484_features.npy
# IMDBid: tt4769836 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt4769836.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt4769836.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt4769836_features.npy
# IMDBid: tt0089652 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt0089652.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt0089652.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt0089652_features.npy
# IMDBid: tt0465494 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt0465494.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt0465494.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt0465494_features.npy
# IMDBid: tt3675748 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt3675748.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt3675748.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt3675748_features.npy
# IMDBid: tt2126362 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt2126362.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt2126362.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt2126362_features.npy
# IMDBid: tt0988083 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt0988083.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt0988083.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt0988083_features.npy
# IMDBid: tt2101341 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt2101341.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt2101341.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt2101341_features.npy
# IMDBid: tt0401997 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt0401997.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt0401997.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt0401997_features.npy
# IMDBid: tt1661461 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt1661461.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt1661461.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt1661461_features.npy
# IMDBid: tt1313139 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt1313139.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt1313139.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt1313139_features.npy
# IMDBid: tt1094661 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt1094661.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt1094661.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt1094661_features.npy
# IMDBid: tt5162658 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt5162658.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt5162658.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt5162658_features.npy
# IMDBid: tt0104839 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt0104839.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt0104839.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt0104839_features.npy
# IMDBid: tt1288558 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt1288558.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt1288558.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt1288558_features.npy
# IMDBid: tt5962210 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt5962210.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt5962210.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt5962210_features.npy
# IMDBid: tt2937696 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt2937696.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt2937696.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt2937696_features.npy
# IMDBid: tt0284363 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt0284363.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt0284363.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt0284363_features.npy
# IMDBid: tt5580390 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt5580390.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt5580390.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt5580390_features.npy
# IMDBid: tt2293750 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt2293750.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt2293750.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt2293750_features.npy
# IMDBid: tt2980472 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt2980472.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt2980472.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt2980472_features.npy
# IMDBid: tt0082186 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt0082186.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt0082186.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt0082186_features.npy
# IMDBid: tt0924129 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt0924129.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt0924129.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt0924129_features.npy
# IMDBid: tt0988595 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt0988595.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt0988595.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt0988595_features.npy
# IMDBid: tt1349482 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt1349482.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt1349482.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt1349482_features.npy
# IMDBid: tt4158096 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt4158096.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt4158096.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt4158096_features.npy
# IMDBid: tt1403241 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt1403241.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt1403241.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt1403241_features.npy
# IMDBid: tt2713642 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt2713642.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt2713642.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt2713642_features.npy
# IMDBid: tt1682940 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt1682940.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt1682940.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt1682940_features.npy
# IMDBid: tt10327354 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt10327354.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt10327354.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt10327354_features.npy
# IMDBid: tt1087842 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt1087842.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt1087842.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt1087842_features.npy
# IMDBid: tt1800302 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt1800302.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt1800302.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt1800302_features.npy
# IMDBid: tt0113855 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt0113855.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt0113855.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt0113855_features.npy
# IMDBid: tt2504022 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt2504022.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt2504022.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt2504022_features.npy
# IMDBid: tt7248248 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt7248248.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt7248248.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt7248248_features.npy
# IMDBid: tt1720164 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt1720164.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt1720164.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt1720164_features.npy
# IMDBid: tt1336621 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt1336621.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt1336621.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt1336621_features.npy
# IMDBid: tt0266987 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt0266987.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt0266987.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt0266987_features.npy
# IMDBid: tt0859635 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt0859635.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt0859635.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt0859635_features.npy
# Total missing files: 141
# Total IMDB IDs with missing files: 47
# Missing files:
# IMDBid: tt2437712 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt2437712.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt2437712.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt2437712_features.npy
# IMDBid: tt0099371 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt0099371.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt0099371.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt0099371_features.npy
# IMDBid: tt2935564 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt2935564.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt2935564.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt2935564_features.npy
# IMDBid: tt0140336 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt0140336.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt0140336.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt0140336_features.npy
# IMDBid: tt4687276 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt4687276.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt4687276.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt4687276_features.npy
# IMDBid: tt0367085 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt0367085.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt0367085.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt0367085_features.npy
# IMDBid: tt0220827 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt0220827.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt0220827.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt0220827_features.npy
# IMDBid: tt0465602 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt0465602.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt0465602.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt0465602_features.npy
# IMDBid: tt2350496 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt2350496.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt2350496.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt2350496_features.npy
# IMDBid: tt1084950 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt1084950.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt1084950.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt1084950_features.npy
# IMDBid: tt0110093 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt0110093.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt0110093.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt0110093_features.npy
# IMDBid: tt1273235 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt1273235.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt1273235.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt1273235_features.npy
# IMDBid: tt4503510 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt4503510.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt4503510.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt4503510_features.npy
# IMDBid: tt1772925 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt1772925.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt1772925.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt1772925_features.npy
# IMDBid: tt2180411 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt2180411.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt2180411.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt2180411_features.npy
# IMDBid: tt0181865 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt0181865.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt0181865.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt0181865_features.npy
# IMDBid: tt0200469 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt0200469.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt0200469.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt0200469_features.npy
# IMDBid: tt0259288 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt0259288.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt0259288.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt0259288_features.npy
# Total missing files: 54
# Total IMDB IDs with missing files: 18
# Missing files:
# IMDBid: tt0190590 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt0190590.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt0190590.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt0190590_features.npy
# IMDBid: tt2383068 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt2383068.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt2383068.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt2383068_features.npy
# IMDBid: tt1488555 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt1488555.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt1488555.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt1488555_features.npy
# IMDBid: tt0758730 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt0758730.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt0758730.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt0758730_features.npy
# IMDBid: tt0389557 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt0389557.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt0389557.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt0389557_features.npy
# IMDBid: tt0498353 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt0498353.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt0498353.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt0498353_features.npy
# IMDBid: tt5084170 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt5084170.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt5084170.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt5084170_features.npy
# IMDBid: tt0405052 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt0405052.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt0405052.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt0405052_features.npy
# IMDBid: tt1104733 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt1104733.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt1104733.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt1104733_features.npy
# IMDBid: tt1924429 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt1924429.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt1924429.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt1924429_features.npy
# IMDBid: tt5027774 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt5027774.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt5027774.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt5027774_features.npy
# IMDBid: tt0990413 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt0990413.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt0990413.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt0990413_features.npy
# IMDBid: tt5580036 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt5580036.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt5580036.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt5580036_features.npy
# IMDBid: tt2524674 (Missing 3 files)
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\textStream_BERT\feature_vectors\feature_vectors\tt2524674.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\audio_fe\logmel_spectrograms\feature_tt2524674.npy
#   Missing file: C:\Users\edjin\OneDrive\Documents\Programming Files\Thesis\SMCA\misc\visualStream_ViT\feature_vectors\tt2524674_features.npy
# Total missing files: 42
# Total IMDB IDs with missing files: 14

# %%
# Function to print a sample from the dataset
def print_sample(dataset, index):
    text_data, audio_data, video_data, label = dataset[index]
    print(f"Sample {index}:")
    print("Text Data:", text_data)
    print("Audio Data:", audio_data)
    print("Video Data:", video_data)
    print("-" * 30)
    print("Text Data Shape:", text_data.shape)
    print("Audio Data Shape:", audio_data.shape)
    print("Video Data Shape:", video_data.shape)
    print("Label:", label)
    print("-" * 30)

# Print a sample from each dataset
print("Training Dataset Sample:")
print_sample(train_dataset, 5)  # Change 5 to any index to view different samples

print("Validation Dataset Sample:")
print_sample(val_dataset, 5)  # Change 5 to any index to view different samples

print("Test Dataset Sample:")
print_sample(test_dataset, 5)  # Change 5 to any index to view different samples
# Out:
# Training Dataset Sample:
# Sample 5:
# Text Data: tensor([ 0.5833, -0.4434, -0.8684,  ..., -0.5946, -0.7582,  0.4914])
# Audio Data: tensor([[[-0.3771, -0.1759, -0.0416,  ...,  0.1546,  0.1987, -0.0360],
#          [-0.3328, -0.3164, -0.1281,  ...,  0.1952,  0.1640, -0.1560],
#          [-0.3665, -0.0383, -0.0546,  ...,  0.1496,  0.1882, -0.1261],
#          ...,
#          [-0.3427, -0.1351, -0.1521,  ...,  0.1828,  0.0589, -0.0564],
#          [-0.3111, -0.0340, -0.1754,  ...,  0.1957,  0.1211, -0.1917],
#          [-0.3148, -0.1266, -0.1421,  ...,  0.0888,  0.1190, -0.0885]]])
# Video Data: tensor([[-0.0010,  0.0832, -0.0718,  ..., -0.3403, -0.1714,  0.2119],
#         [-0.0048,  0.1294,  0.0153,  ..., -0.3646, -0.1083,  0.1913],
#         [-0.0551, -0.1336, -0.1215,  ..., -0.0564, -0.0422,  0.1340],
#         ...,
#         [ 0.1419,  0.0912, -0.1560,  ...,  0.0119, -0.0102,  0.0301],
#         [-0.0872, -0.2430,  0.1118,  ..., -0.0621,  0.2087, -0.1113],
#         [-0.1739,  0.0709, -0.0382,  ..., -0.2455,  0.0502,  0.0368]])
# ------------------------------
# Text Data Shape: torch.Size([1024])
# Audio Data Shape: torch.Size([1, 197, 768])
# Video Data Shape: torch.Size([79, 768])
# Label: green
# ------------------------------
# Validation Dataset Sample:
# Sample 5:
# Text Data: tensor([ 0.4415, -0.4966, -0.9276,  ..., -1.2775, -0.4691,  0.0831])
# Audio Data: tensor([[[-0.3337, -0.3759,  0.0776,  ...,  0.0408, -0.0033,  0.0298],
#          [-0.3167, -0.4895, -0.2423,  ..., -0.1506, -0.1006, -0.1715],
#          [-0.2823, -0.3609, -0.1240,  ..., -0.0807, -0.0330, -0.0870],
#          ...,
#          [-0.3375, -0.2663, -0.1103,  ..., -0.0570, -0.1846, -0.0604],
#          [-0.2961, -0.2089, -0.0880,  ..., -0.0903, -0.1686, -0.1279],
#          [-0.2786, -0.3473, -0.1485,  ..., -0.0697, -0.0836,  0.0522]]])
# Video Data: tensor([[-0.0268,  0.0399,  0.0295,  ..., -0.0527,  0.1469, -0.1447],
#         [ 0.0608, -0.3021, -0.0600,  ...,  0.1177, -0.0017, -0.0252],
#         [-0.0069,  0.0165,  0.5734,  ...,  0.0693, -0.0971,  0.1877],
#         ...,
#         [ 0.0660,  0.1996, -0.3764,  ...,  0.0320,  0.1388, -0.1564],
#         [-0.2534, -0.2746, -0.1146,  ..., -0.0148,  0.1282, -0.0510],
#         [-0.1540, -0.2513, -0.0456,  ...,  0.0250,  0.0634, -0.1978]])
# ------------------------------
# Text Data Shape: torch.Size([1024])
# Audio Data Shape: torch.Size([1, 197, 768])
# Video Data Shape: torch.Size([144, 768])
# Label: green
# ------------------------------
# Test Dataset Sample:
# Sample 5:
# Text Data: tensor([-0.5624, -0.2706, -1.5187,  ..., -0.3882,  0.5636,  0.9671])
# Audio Data: tensor([[[-0.2875, -0.1248, -0.0308,  ...,  0.1127,  0.1368, -0.0538],
#          [-0.2646, -0.3631, -0.1015,  ...,  0.0755,  0.1012, -0.1602],
#          [-0.2705,  0.0182, -0.1390,  ...,  0.2170,  0.0647, -0.1205],
#          ...,
#          [-0.1292, -0.1282, -0.1343,  ...,  0.0705,  0.1844, -0.1537],
#          [-0.0744, -0.0614, -0.0788,  ...,  0.0920,  0.1175, -0.1123],
#          [-0.1969, -0.1950, -0.0722,  ...,  0.0083,  0.2045, -0.0926]]])
# Video Data: tensor([[-0.2415, -0.0285, -0.1641,  ..., -0.2523,  0.0991,  0.0137],
#         [-0.3218, -0.0350,  0.0938,  ..., -0.2883, -0.2128, -0.0523],
#         [-0.3248, -0.3166, -0.0199,  ...,  0.0237,  0.1347, -0.0781],
#         ...,
#         [ 0.0809, -0.2654,  0.0813,  ...,  0.2965, -0.1312,  0.3320],
#         [ 0.0778, -0.3378,  0.1288,  ...,  0.3188, -0.0938,  0.3654],
#         [-0.0646, -0.2982,  0.0237,  ...,  0.2359, -0.1241,  0.2949]])
# ------------------------------
# Text Data Shape: torch.Size([1024])
# Audio Data Shape: torch.Size([1, 197, 768])
# Video Data Shape: torch.Size([104, 768])
# Label: red
# ------------------------------

# %%
def print_dataloader_samples(dataloader, num_batches=1):
    """
    Print a few batches from the DataLoader to inspect the data.

    Args:
        dataloader (DataLoader): The DataLoader instance.
        num_batches (int): The number of batches to print.
    """
    for i, batch in enumerate(dataloader):
        if i >= num_batches:
            break
        
        text_data, audio_data, video_data, labels = batch

        # Convert labels to a list of integers if they are tensors
        if isinstance(labels, torch.Tensor):
            labels = labels.tolist()

        print(f"Batch {i}:")
        print("Text Data Shape:", text_data.shape)
        print("Audio Data Shape:", audio_data.shape)
        print("Video Data Shape:", video_data.shape)
        print("Labels:", labels)
        print("-" * 30)

# Print a few batches from the training DataLoader
print("Training DataLoader Samples:")
print_dataloader_samples(train_dataloader, num_batches=5)

# Print a few batches from the validation DataLoader
print("Validation DataLoader Samples:")
print_dataloader_samples(val_dataloader, num_batches=5)

# Print a few batches from the validation DataLoader
print("Validation DataLoader Samples:")
print_dataloader_samples(test_dataloader, num_batches=5)
# Out:
# Training DataLoader Samples:
# Batch 0:
# Text Data Shape: torch.Size([8, 1024])
# Audio Data Shape: torch.Size([8, 1, 197, 768])
# Video Data Shape: torch.Size([8, 167, 768])
# Labels: [0, 1, 1, 1, 1, 0, 0, 1]
# ------------------------------
# Batch 1:
# Text Data Shape: torch.Size([8, 1024])
# Audio Data Shape: torch.Size([8, 1, 197, 768])
# Video Data Shape: torch.Size([8, 141, 768])
# Labels: [1, 1, 0, 0, 1, 1, 1, 1]
# ------------------------------
# Batch 2:
# Text Data Shape: torch.Size([8, 1024])
# Audio Data Shape: torch.Size([8, 1, 197, 768])
# Video Data Shape: torch.Size([8, 142, 768])
# Labels: [1, 1, 1, 1, 0, 1, 1, 1]
# ------------------------------
# Batch 3:
# Text Data Shape: torch.Size([8, 1024])
# Audio Data Shape: torch.Size([8, 1, 197, 768])
# Video Data Shape: torch.Size([8, 141, 768])
# Labels: [1, 1, 1, 1, 1, 0, 1, 1]
# ------------------------------
# Batch 4:
# Text Data Shape: torch.Size([8, 1024])
# Audio Data Shape: torch.Size([8, 1, 197, 768])
# Video Data Shape: torch.Size([8, 148, 768])
# Labels: [1, 0, 1, 1, 1, 0, 1, 1]
# ------------------------------
# Validation DataLoader Samples:
# Batch 0:
# Text Data Shape: torch.Size([8, 1024])
# Audio Data Shape: torch.Size([8, 1, 197, 768])
# Video Data Shape: torch.Size([8, 144, 768])
# Labels: [1, 1, 1, 1, 1, 1, 1, 1]
# ------------------------------
# Batch 1:
# Text Data Shape: torch.Size([8, 1024])
# Audio Data Shape: torch.Size([8, 1, 197, 768])
# Video Data Shape: torch.Size([8, 234, 768])
# Labels: [1, 1, 1, 1, 1, 1, 1, 1]
# ------------------------------
# Batch 2:
# Text Data Shape: torch.Size([8, 1024])
# Audio Data Shape: torch.Size([8, 1, 197, 768])
# Video Data Shape: torch.Size([8, 160, 768])
# Labels: [1, 1, 0, 1, 1, 1, 1, 1]
# ------------------------------
# Batch 3:
# Text Data Shape: torch.Size([8, 1024])
# Audio Data Shape: torch.Size([8, 1, 197, 768])
# Video Data Shape: torch.Size([8, 151, 768])
# Labels: [1, 0, 1, 0, 0, 0, 1, 1]
# ------------------------------
# Batch 4:
# Text Data Shape: torch.Size([8, 1024])
# Audio Data Shape: torch.Size([8, 1, 197, 768])
# Video Data Shape: torch.Size([8, 162, 768])
# Labels: [1, 1, 1, 1, 1, 1, 1, 1]
# ------------------------------
# Validation DataLoader Samples:
# Batch 0:
# Text Data Shape: torch.Size([8, 1024])
# Audio Data Shape: torch.Size([8, 1, 197, 768])
# Video Data Shape: torch.Size([8, 162, 768])
# Labels: [1, 0, 1, 1, 1, 0, 1, 0]
# ------------------------------
# Batch 1:
# Text Data Shape: torch.Size([8, 1024])
# Audio Data Shape: torch.Size([8, 1, 197, 768])
# Video Data Shape: torch.Size([8, 155, 768])
# Labels: [1, 1, 1, 1, 1, 1, 1, 1]
# ------------------------------
# Batch 2:
# Text Data Shape: torch.Size([8, 1024])
# Audio Data Shape: torch.Size([8, 1, 197, 768])
# Video Data Shape: torch.Size([8, 153, 768])
# Labels: [1, 1, 1, 1, 1, 1, 1, 1]
# ------------------------------
# Batch 3:
# Text Data Shape: torch.Size([8, 1024])
# Audio Data Shape: torch.Size([8, 1, 197, 768])
# Video Data Shape: torch.Size([8, 146, 768])
# Labels: [1, 0, 1, 1, 1, 1, 1, 1]
# ------------------------------
# Batch 4:
# Text Data Shape: torch.Size([8, 1024])
# Audio Data Shape: torch.Size([8, 1, 197, 768])
# Video Data Shape: torch.Size([8, 156, 768])
# Labels: [1, 1, 1, 0, 1, 1, 1, 1]
# ------------------------------

# %%
class GatedMultimodalUnit(torch.nn.Module):
    def __init__(self, text_dim, audio_dim, video_dim, output_dim):
        super(GatedMultimodalUnit, self).__init__()
        
        # Linear transformation for text features
        self.text_linear = nn.Linear(text_dim, output_dim)
        
        # Convolutional layers for audio and video features
        self.audio_conv = nn.Conv1d(audio_dim, output_dim, kernel_size=1)
        self.video_conv = nn.Conv1d(video_dim, output_dim, kernel_size=1)
        
        # Activation functions
        self.activation = nn.Tanh()
        self.gate_activation = nn.Sigmoid() # Logistic()
        
        # Weight matrices for each modality
        self.W1 = nn.Parameter(torch.Tensor(output_dim, output_dim))
        self.W2 = nn.Parameter(torch.Tensor(output_dim, output_dim))
        self.W3 = nn.Parameter(torch.Tensor(output_dim, output_dim))
        
        
        # Gating matrices
        self.Y1 = nn.Parameter(torch.Tensor(output_dim, output_dim * 3))
        self.Y2 = nn.Parameter(torch.Tensor(output_dim, output_dim * 3))
        self.Y3 = nn.Parameter(torch.Tensor(output_dim, output_dim * 3))
        
        # Initialize weights
        self._initialize_weights()
        
    def _initialize_weights(self):
        
        # Initialize weight matrices
        init.xavier_uniform_(self.W1)
        init.xavier_uniform_(self.W2)
        init.xavier_uniform_(self.W3)
        
        # Initialize gating matrices
        init.xavier_uniform_(self.Y1)
        init.xavier_uniform_(self.Y2)
        init.xavier_uniform_(self.Y3)
        
        
    def forward(self, text_features, audio_features, video_features):
        
       # Process text features
        x_t = self.text_linear(text_features)  # Shape: [batch_size, output_dim]
        h1 = self.activation(torch.matmul(x_t, self.W1))  # Shape: [batch_size, output_dim]

        print('-'*50)
        print("x_t Shape:", x_t.shape)
        print("h1 Shape:", h1.shape)
        print("W1 Shape:", self.W1.shape)


        # Process audio features
        audio_features = audio_features.squeeze(1).permute(0, 2, 1)  # Shape: [batch_size, audio_dim, sequence_length]
        x_a = self.audio_conv(audio_features).mean(dim=-1)  # Shape: [batch_size, output_dim]
        h2 = self.activation(torch.matmul(x_a, self.W2))  # Shape: [batch_size, output_dim]
        
        print('-'*50)
        print("x_a Shape:", x_a.shape)
        print("h2 Shape:", h2.shape)
        print("W2 Shape:", self.W2.shape)
        
        # Process video features
        video_features = video_features.permute(0, 2, 1)  # Shape: [batch_size, video_dim, sequence_length]
        x_v = self.video_conv(video_features).mean(dim=-1)  # Shape: [batch_size, output_dim]
        h3 = self.activation(torch.matmul(x_v, self.W3))  # Shape: [batch_size, output_dim]
        
        print('-'*50)
        print("x_v Shape:", x_v.shape)
        print("h3 Shape:", h3.shape)
        print("W13 Shape:", self.W3.shape)
        
        # Combine processed features
        x = torch.cat((x_t, x_a, x_v), dim=1)
               
        # Compute gating weights for each modality
        z1 = self.gate_activation(torch.matmul(x, self.Y1.t()))
        z2 = self.gate_activation(torch.matmul(x, self.Y2.t()))
        z3 = self.gate_activation(torch.matmul(x, self.Y3.t()))
        
        print('-'*50)
        print("z1 Shape:", z1.shape)
        print("z2 Shape:", z2.shape)
        print("z3 Shape:", z3.shape)
        
        # Calculate final output
        h = z1 * h1 + z2 * h2 + z3 * h3
        return h

# %%
# Define dimensions
text_dim = 1024
audio_dim = 768  # Number of channels in audio data
video_dim = 768  # Number of channels in video data
output_dim = 512  # You can set this to any value, depending on your requirements

# Instantiate the GMU model
gmu = GatedMultimodalUnit(text_dim, audio_dim, video_dim, output_dim)

# Use DataLoader to get a batch of data
for batch in train_dataloader:  # You can use any DataLoader (train_dataloader, val_dataloader, etc.)
    text_data, audio_data, video_data, _ = batch
    
    # Feed the entire batch to the GMU model
    with torch.no_grad():
        output = gmu(text_data, audio_data, video_data)
    
    # Print the output shape
    print('-'*50)
    print("GMU Output Shape:", output.shape)
    print("GMU Output: ", output)
    
    # Break after the first batch for testing purposes
    break
# Out:
# --------------------------------------------------
# x_t Shape: torch.Size([8, 512])
# h1 Shape: torch.Size([8, 512])
# W1 Shape: torch.Size([512, 512])
# --------------------------------------------------
# x_a Shape: torch.Size([8, 512])
# h2 Shape: torch.Size([8, 512])
# W2 Shape: torch.Size([512, 512])
# --------------------------------------------------
# x_v Shape: torch.Size([8, 512])
# h3 Shape: torch.Size([8, 512])
# W13 Shape: torch.Size([512, 512])
# --------------------------------------------------
# z1 Shape: torch.Size([8, 512])
# z2 Shape: torch.Size([8, 512])
# z3 Shape: torch.Size([8, 512])
# --------------------------------------------------
# GMU Output Shape: torch.Size([8, 512])
# GMU Output:  tensor([[-0.0544,  0.0315,  0.1469,  ...,  0.0982,  0.0119, -0.0439],
#         [-0.3414, -0.0562,  0.1583,  ...,  0.1756, -0.1139, -0.1555],
#         [-0.1362,  0.0417,  0.0033,  ...,  0.1210, -0.0395, -0.1473],
#         ...,
#         [-0.1897, -0.0133,  0.0968,  ...,  0.1642, -0.0928,  0.0761],
#         [-0.1032,  0.0329,  0.1784,  ...,  0.0549,  0.0278,  0.0005],
#         [-0.1788, -0.1369,  0.0542,  ..., -0.0558,  0.1731,  0.1193]])
